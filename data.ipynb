# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dataset\Webis-CausalQA-22-v-1.0\Webis-CausalQA-22-v-1.0\input\\random-splits\\naturalquestions_train_random_split.csv')

# %%
df.head(1).to_dict()
# Out:
# {'id': {0: -4908744603776823108},
#  'question': {0: 'what is the main cause of habitat destruction?'},
#  'question_processed': {0: 'what is the main cause of habitat destruction?'},
# ...
