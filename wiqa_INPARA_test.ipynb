# %%
import os
import json
import random
from WIQACausalBuilder import WIQACausalBuilder

# Set random seed for reproducibility
random.seed(42)

# Load data
json_path = r'E:\PHD\01\wiqa_filtered_INPARA_EFFECT.json'
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

print(f"Total datapoints in file: {len(data)}")
print(f"Processing first 10 datapoints...\n")

# Select first 10 datapoints
datapoints = data[:300]

# Store results
results = []
# Out:
# Total datapoints in file: 1655
# Processing first 10 datapoints...

# %%
for idx, datapoint in enumerate(datapoints, 1):
    print("=" * 80)
    print(f"Processing datapoint {idx}/10")
    print("=" * 80)
    print(f"Question: {datapoint['question_stem']}")
    print(f"Gold answer: {datapoint['answer_label']} ({datapoint['answer_label_as_choice']})")
    print()
    
    try:
        # Initialize builder
        wiqa = WIQACausalBuilder(datapoint)
        
        # Step 1: Extract start and target entities
        print("Step 1: Extracting entities...")
        info = wiqa.extract_start_entity()
        start = info["cause_event"]
        target = info["outcome_base"]
        print(f"  Cause: '{start}'")
        print(f"  Outcome base: '{target}'")
        print()
        
        # Step 2: BFS expansion
        print("Step 2: BFS expansion...")
        bfs = wiqa.expand_toward_target(
            start_X=start, 
            target_Y=target, 
            max_depth=5, 
            max_relations_per_node=5
        )
        print(f"  Triples found: {len(bfs['triples'])}")
        print(f"  Nodes visited: {len(bfs['visited'])}")
        print(f"  Close hits: {len(bfs['close_hits'])}")
        print()
        
        # Step 3: Bridge close hits and extract causal chain
        print("Step 3: Bridging and chain extraction...")
        if bfs["close_hits"]:
            triples_with_bridges = wiqa.bridge_close_hits(
                triples=bfs["triples"],
                close_hits=bfs["close_hits"],
                Y=target,
                max_bridge_nodes=3,
            )
        else:
            triples_with_bridges = bfs["triples"]
        
        chain_result = wiqa.get_causal_chain(triples_with_bridges, start_X=start, target_Y=target)
        print(f"  Paths found: {chain_result['num_paths']}")
        print()
        
        # Step 4: Generate description
        print("Step 4: Generating description...")
        description = wiqa.causal_chain_to_text(chain_result, bfs)
        print()
        
        # Step 5: LLM reasoning
        print("Step 5: Final reasoning...")
        reasoning_result = wiqa.reason_with_description(description, chain_result=chain_result)
        
        # Check result
        gold_label = datapoint['answer_label']
        pred_label = reasoning_result['predicted_answer']
        gold_norm = gold_label.strip().lower().replace(" ", "_")
        pred_norm = pred_label.strip().lower().replace(" ", "_")
        is_correct = (pred_norm == gold_norm)
        
        print(f"\nPrediction: {pred_label}")
        print(f"Gold: {gold_label}")
        print(f"Result: {'✓ CORRECT' if is_correct else '✗ WRONG'}")
        
        # Store result
        result_entry = {
            'index': idx,
            'question': datapoint['question_stem'],
            'gold_answer': gold_label,
            'gold_choice': datapoint['answer_label_as_choice'],
            'predicted_answer': pred_label,
            'predicted_choice': reasoning_result['predicted_choice'],
            'is_correct': is_correct,
            'confidence': reasoning_result['confidence'],
            'effect_on_base': reasoning_result.get('effect_on_base', 'N/A'),
            'reasoning': reasoning_result['reasoning'],
            'num_paths': chain_result['num_paths'],
            'num_triples': len(bfs['triples']),
        }
        results.append(result_entry)
        
    except Exception as e:
        print(f"\n✗ ERROR processing datapoint {idx}: {str(e)}")
        import traceback
        traceback.print_exc()
        
        # Store error result
        result_entry = {
            'index': idx,
            'question': datapoint['question_stem'],
            'gold_answer': datapoint['answer_label'],
            'gold_choice': datapoint['answer_label_as_choice'],
            'predicted_answer': 'ERROR',
            'predicted_choice': 'ERROR',
            'is_correct': False,
            'confidence': 'N/A',
            'effect_on_base': 'N/A',
            'reasoning': f'Error: {str(e)}',
            'num_paths': 0,
            'num_triples': 0,
        }
        results.append(result_entry)
    
    print()

# Summary
print("=" * 80)
print("SUMMARY")
print("=" * 80)
correct_count = sum(1 for r in results if r['is_correct'])
total_count = len(results)
accuracy = correct_count / total_count if total_count > 0 else 0

print(f"Total processed: {total_count}")
print(f"Correct: {correct_count}")
print(f"Wrong: {total_count - correct_count}")
print(f"Accuracy: {accuracy:.2%}")
print()

# Display results table
print("Detailed Results:")
print("-" * 80)
for r in results:
    status = "✓" if r['is_correct'] else "✗"
    print(f"{status} [{r['index']}] Gold: {r['gold_answer']:10s} | Pred: {r['predicted_answer']:10s} | Conf: {r['confidence']}")
print("-" * 80)

# Save results to JSON
output_path = 'single_question_demo_results.json'
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)
print(f"\nResults saved to: {output_path}")
# Out:
# ================================================================================
# Processing datapoint 1/10
# ================================================================================
# Question: suppose the female is sterile happens, how will it affect LESS rabbits.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'the female is sterile happens'
#   Outcome base: 'rabbits'
#
# Step 2: BFS expansion...
# find_causal_relations: X = the female is sterile happens , Y = rabbits
# is_same_variable: LLM 判定 rabbit offspring <-> rabbits = part_of
# find_causal_relations: X = rabbit offspring , Y = rabbits
#   Triples found: 2
#   Nodes visited: 3
#   Close hits: 1
#
# Step 3: Bridging and chain extraction...
#   Paths found: 1
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "The only causal path shows that the female being sterile suppresses rabbit offspring, which in turn promotes rabbits. This strongly suggests a decrease in the number of rabbits.",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id": 1,
#       "plau
#
# Prediction: more
# Gold: more
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 2/10
# ================================================================================
# Question: suppose less water vapor forms happens, how will it affect MORE clouds forming.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'less water vapor forms happens'
#   Outcome base: 'clouds forming'
#
# Step 2: BFS expansion...
# find_causal_relations: X = less water vapor forms happens , Y = clouds forming
# is_same_variable: LLM 判定 water droplets condensing <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud formation <-> clouds forming = identical
# find_causal_relations: X = water droplets condensing , Y = clouds forming
# is_same_variable: LLM 判定 visible water vapor <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 increased cloud density <-> clouds forming = part_of
# find_causal_relations: X = cloud formation , Y = clouds forming
# is_same_variable: LLM 判定 water vapor condensation <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 rising air <-> clouds forming = causal_but_separate
# find_causal_relations: X = visible water vapor , Y = clouds forming
# is_same_variable: LLM 判定 water droplets <-> clouds forming = part_of
# is_same_variable: LLM 判定 condensation nuclei <-> clouds forming = causal_but_separate
# find_causal_relations: X = increased cloud density , Y = clouds forming
# is_same_variable: LLM 判定 water droplet formation <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud opacity <-> clouds forming = part_of
# find_causal_relations: X = water vapor condensation , Y = clouds forming
# is_same_variable: LLM 判定 water droplets <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud nuclei <-> clouds forming = part_of
# find_causal_relations: X = rising air , Y = clouds forming
# is_same_variable: LLM 判定 cooling <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 water vapor condensation <-> clouds forming = causal_but_separate
# find_causal_relations: X = water droplets , Y = clouds forming
# is_same_variable: LLM 判定 evaporation <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 condensation <-> clouds forming = part_of
# find_causal_relations: X = condensation nuclei , Y = clouds forming
# is_same_variable: LLM 判定 water droplet formation <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud seeding <-> clouds forming = causal_but_separate
# find_causal_relations: X = water droplet formation , Y = clouds forming
# is_same_variable: LLM 判定 increased humidity <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 cloud condensation nuclei <-> clouds forming = causal_but_separate
# find_causal_relations: X = cloud opacity , Y = clouds forming
# is_same_variable: LLM 判定 light scattering <-> clouds forming = part_of
# is_same_variable: LLM 判定 water droplet density <-> clouds forming = causal_but_separate
# find_causal_relations: X = cloud nuclei , Y = clouds forming
# is_same_variable: LLM 判定 water droplet formation <-> clouds forming = part_of
# is_same_variable: LLM 判定 condensation <-> clouds forming = part_of
# find_causal_relations: X = cooling , Y = clouds forming
# is_same_variable: LLM 判定 water vapor condensation <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 air pressure decrease <-> clouds forming = causal_but_separate
# find_causal_relations: X = evaporation , Y = clouds forming
# is_same_variable: LLM 判定 water vapor <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 cooling <-> clouds forming = causal_but_separate
# find_causal_relations: X = condensation , Y = clouds forming
# is_same_variable: LLM 判定 water droplets <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud nuclei <-> clouds forming = part_of
# find_causal_relations: X = cloud seeding , Y = clouds forming
# is_same_variable: LLM 判定 condensation nuclei <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 increased cloud formation <-> clouds forming = identical
# find_causal_relations: X = increased humidity , Y = clouds forming
# is_same_variable: LLM 判定 water vapor concentration <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 cloud condensation nuclei activation <-> clouds forming = part_of
# find_causal_relations: X = cloud condensation nuclei , Y = clouds forming
# is_same_variable: LLM 判定 water droplet formation <-> clouds forming = part_of
# is_same_variable: LLM 判定 cloud particle growth <-> clouds forming = part_of
# find_causal_relations: X = light scattering , Y = clouds forming
# is_same_variable: LLM 判定 reduced visibility <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 diffuse light <-> clouds forming = causal_but_separate
# find_causal_relations: X = water droplet density , Y = clouds forming
# is_same_variable: LLM 判定 cloud condensation nuclei <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 cloud formation rate <-> clouds forming = identical
# find_causal_relations: X = air pressure decrease , Y = clouds forming
# is_same_variable: LLM 判定 rising air <-> clouds forming = causal_but_separate
# is_same_variable: LLM 判定 cooling air <-> clouds forming = causal_but_separate
#   Triples found: 42
#   Nodes visited: 30
#   Close hits: 20
#
# Step 3: Bridging and chain extraction...
#   Paths found: 3
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "medium",
#   "reasoning": "Two out of three paths suggest that less water vapor leads to fewer clouds. While one path suggests an increase in cloud density, the counterfactual reasoning (imagining no water vapor) strongly points towards a decrease in cloud formation.",
#   "scores": {
#     "more": 0.25,
#     "less": 0.6,
#     "no_effect": 0.15
#   },
#   "paths_eval": [
#
# Prediction: less
# Gold: less
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 3/10
# ================================================================================
# Question: suppose less time camping happens, how will it affect a LESS EXTENSIVE camping trip.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'less time camping happens'
#   Outcome base: 'camping trip extent'
#
# Step 2: BFS expansion...
# find_causal_relations: X = less time camping happens , Y = camping trip extent
#   Triples found: 1
#   Nodes visited: 2
#   Close hits: 0
#
# Step 3: Bridging and chain extraction...
#   Paths found: 1
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "There is only one causal path, and it directly suppresses camping trip extent. Removing the cause (less time camping) would logically lead to a less extensive camping trip.",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id": 1,
#       "
#
# Prediction: more
# Gold: more
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 4/10
# ================================================================================
# Question: suppose more oil is processed happens, how will it affect MORE oil arriving at gas stations.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'more oil is processed happens'
#   Outcome base: 'oil arriving at gas stations'
#
# Step 2: BFS expansion...
# find_causal_relations: X = more oil is processed happens , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil supply <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 refined gasoline <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil supply , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil refining <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 oil transportation <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = refined gasoline , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 gas station deliveries <-> oil arriving at gas stations = identical
# is_same_variable: LLM 判定 fuel pumps <-> oil arriving at gas stations = part_of
# find_causal_relations: X = oil refining , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 refined gasoline <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 diesel fuel <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 gasoline distribution <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil transportation , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil availability at refineries <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 oil delivery to pipelines <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = gas station deliveries , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil shipments <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 fuel inventory <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = fuel pumps , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 fuel flow <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 pressure increase <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = diesel fuel , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil refining <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 truck transport <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = gasoline distribution , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 gas station supply <-> oil arriving at gas stations = identical
# is_same_variable: LLM 判定 fuel availability <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil availability at refineries , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil shipments to gas stations <-> oil arriving at gas stations = identical
# is_same_variable: LLM 判定 gasoline production <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil delivery to pipelines , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 pipeline pressure <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 oil flow <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil shipments , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil refinery output <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 gasoline production <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 fuel availability <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = fuel inventory , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil refinery production <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 fuel shipments <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = fuel flow , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 engine power <-> oil arriving at gas stations = weakly_related
# is_same_variable: LLM 判定 vehicle movement <-> oil arriving at gas stations = weakly_related
# find_causal_relations: X = pressure increase , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 pump activation <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 oil flow <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = truck transport , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil delivery <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 gas station supply <-> oil arriving at gas stations = identical
# find_causal_relations: X = gas station supply , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil deliveries <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 fuel availability <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = fuel availability , Y = oil arriving at gas stations
# is_same_variable: LLM 判定 oil refining <-> oil arriving at gas stations = causal_but_separate
# is_same_variable: LLM 判定 oil transportation <-> oil arriving at gas stations = causal_but_separate
# find_causal_relations: X = oil shipments to gas stations , Y = oil arriving at gas stations
#   Triples found: 39
#   Nodes visited: 31
#   Close hits: 5
#
# Step 3: Bridging and chain extraction...
#   Paths found: 14
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "more",
#   "confidence": "high",
#   "reasoning": "All 7 causal paths lead from 'more oil is processed happens' to 'oil arriving at gas stations' through a series of promoting (+) steps. The shortest path length is 3, indicating strong and direct connections.",
#   "scores": {
#     "more": 1.0,
#     "less": 0.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#
# Prediction: more
# Gold: more
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 5/10
# ================================================================================
# Question: suppose you inhale more air from the outside happens, how will it affect there will be less oxygen in your blood.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'you inhale more air from the outside happens'
#   Outcome base: 'oxygen in your blood'
#
# Step 2: BFS expansion...
# find_causal_relations: X = you inhale more air from the outside happens , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen intake <-> oxygen in your blood = causal_but_separate
# is_same_variable: LLM 判定 lung volume <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = oxygen intake , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen in lungs <-> oxygen in your blood = causal_but_separate
# is_same_variable: LLM 判定 oxygen in bloodstream <-> oxygen in your blood = identical
# find_causal_relations: X = lung volume , Y = oxygen in your blood
# is_same_variable: LLM 判定 air pressure <-> oxygen in your blood = causal_but_separate
# is_same_variable: LLM 判定 oxygen intake <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = oxygen in lungs , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen diffusion into blood <-> oxygen in your blood = part_of
# find_causal_relations: X = oxygen in bloodstream , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen delivery to tissues <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = air pressure , Y = oxygen in your blood
# is_same_variable: LLM 判定 lung volume <-> oxygen in your blood = causal_but_separate
# is_same_variable: LLM 判定 oxygen intake <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = oxygen diffusion into blood , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen levels in blood <-> oxygen in your blood = identical
# is_same_variable: LLM 判定 red blood cell saturation <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = oxygen delivery to tissues , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen levels in blood <-> oxygen in your blood = identical
# is_same_variable: LLM 判定 red blood cell oxygenation <-> oxygen in your blood = identical
# find_causal_relations: X = oxygen levels in blood , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen delivery to tissues <-> oxygen in your blood = causal_but_separate
# is_same_variable: LLM 判定 cellular respiration <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = red blood cell saturation , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen delivery to tissues <-> oxygen in your blood = causal_but_separate
# find_causal_relations: X = red blood cell oxygenation , Y = oxygen in your blood
# is_same_variable: LLM 判定 oxygen delivery to tissues <-> oxygen in your blood = causal_but_separate
#   Triples found: 18
#   Nodes visited: 12
#   Close hits: 5
#
# Step 3: Bridging and chain extraction...
#   Paths found: 15
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "All paths lead from inhaling more air to less oxygen in your blood. While some paths are longer, they all ultimately result in a decrease of oxygen in the blood.",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id": 1,
#
# Prediction: more
# Gold: less
# Result: ✗ WRONG
#
# ================================================================================
# Processing datapoint 6/10
# ================================================================================
# Question: suppose lava chambers are aggravated with build up pressure happens, how will it affect there is no lava chambers with pressure.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'lava chambers are aggravated with build up pressure happens'
#   Outcome base: 'lava chambers with pressure'
#
# Step 2: BFS expansion...
# find_causal_relations: X = lava chambers are aggravated with build up pressure happens , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 lava chamber instability <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = pressure buildup , Y = lava chambers with pressure
# is_same_variable: LLM 判定 lava chamber expansion <-> lava chambers with pressure = causal_but_separate
# is_same_variable: LLM 判定 magma flow increase <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = lava chamber instability , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 magma movement <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = lava chamber expansion , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 chamber instability <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = magma flow increase , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 lava chamber volume increase <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = magma movement , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 lava chambers <-> lava chambers with pressure = part_of
# find_causal_relations: X = chamber instability , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure fluctuations <-> lava chambers with pressure = causal_but_separate
# is_same_variable: LLM 判定 magma movement <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = lava chamber volume increase , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 chamber wall stress <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = lava chambers , Y = lava chambers with pressure
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 magma flow <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = pressure fluctuations , Y = lava chambers with pressure
# is_same_variable: LLM 判定 lava chamber instability <-> lava chambers with pressure = causal_but_separate
# is_same_variable: LLM 判定 magma movement <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = chamber wall stress , Y = lava chambers with pressure
# is_same_variable: LLM 判定 lava chamber deformation <-> lava chambers with pressure = causal_but_separate
# is_same_variable: LLM 判定 increased risk of eruption <-> lava chambers with pressure = causal_but_separate
# find_causal_relations: X = magma flow , Y = lava chambers with pressure
# is_same_variable: LLM 判定 lava chambers <-> lava chambers with pressure = part_of
# is_same_variable: LLM 判定 pressure buildup <-> lava chambers with pressure = part_of
#   Triples found: 24
#   Nodes visited: 14
#   Close hits: 10
#
# Step 3: Bridging and chain extraction...
#   Paths found: 11
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "more",
#   "confidence": "high",
#   "reasoning": "All 7 causal paths lead from aggravated lava chambers with pressure buildup to an increase in 'lava chambers with pressure'. The shortest path only has 2 steps, making it a strong indicator. ",
#   "scores": {
#     "more": 1.0,
#     "less": 0.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id":
#
# Prediction: less
# Gold: less
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 7/10
# ================================================================================
# Question: suppose there are less nucleus happens, how will it affect MORE proteins being synthesized.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'less nucleus happens'
#   Outcome base: 'proteins being synthesized'
#
# Step 2: BFS expansion...
# find_causal_relations: X = less nucleus happens , Y = proteins being synthesized
# is_same_variable: LLM 判定 protein production <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 RNA synthesis <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = protein production , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 ribosome activity <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = RNA synthesis , Y = proteins being synthesized
# is_same_variable: LLM 判定 messenger RNA <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 ribosomes binding <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = amino acid chains , Y = proteins being synthesized
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# is_same_variable: LLM 判定 protein structure <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = ribosome activity , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# find_causal_relations: X = messenger RNA , Y = proteins being synthesized
# is_same_variable: LLM 判定 ribosomes binding <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 protein synthesis initiation <-> proteins being synthesized = part_of
# find_causal_relations: X = ribosomes binding , Y = proteins being synthesized
# is_same_variable: LLM 判定 mRNA translation <-> proteins being synthesized = part_of
# is_same_variable: LLM 判定 amino acid chain formation <-> proteins being synthesized = part_of
# find_causal_relations: X = protein folding , Y = proteins being synthesized
# is_same_variable: LLM 判定 functional proteins <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 active enzymes <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = protein structure , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid sequence <-> proteins being synthesized = part_of
# is_same_variable: LLM 判定 enzyme activity <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# find_causal_relations: X = protein synthesis initiation , Y = proteins being synthesized
# is_same_variable: LLM 判定 ribosome assembly <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 mRNA translation <-> proteins being synthesized = part_of
# find_causal_relations: X = mRNA translation , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 polypeptide formation <-> proteins being synthesized = identical
# find_causal_relations: X = amino acid chain formation , Y = proteins being synthesized
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# is_same_variable: LLM 判定 protein structure <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = functional proteins , Y = proteins being synthesized
# is_same_variable: LLM 判定 protein synthesis <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# find_causal_relations: X = active enzymes , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# find_causal_relations: X = amino acid sequence , Y = proteins being synthesized
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# is_same_variable: LLM 判定 protein structure <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 enzyme activity <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = enzyme activity , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid availability <-> proteins being synthesized = causal_but_separate
# is_same_variable: LLM 判定 ribosome function <-> proteins being synthesized = causal_but_separate
# find_causal_relations: X = ribosome assembly , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
# find_causal_relations: X = polypeptide formation , Y = proteins being synthesized
# is_same_variable: LLM 判定 amino acid chains <-> proteins being synthesized = identical
# is_same_variable: LLM 判定 protein folding <-> proteins being synthesized = part_of
#   Triples found: 38
#   Nodes visited: 21
#   Close hits: 24
#
# Step 3: Bridging and chain extraction...
#   Paths found: 70
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "All causal paths start with 'less nucleus happens' which suppresses protein production. This suppression, even through multi-step pathways, consistently leads to a decrease in 'proteins being synthesized'. ",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id": 1
#
# Prediction: less
# Gold: more
# Result: ✗ WRONG
#
# ================================================================================
# Processing datapoint 8/10
# ================================================================================
# Question: suppose more seeds get caught in the fur of animals happens, how will it affect MORE seed dispersal.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'more seeds get caught in the fur of animals'
#   Outcome base: 'seed dispersal'
#
# Step 2: BFS expansion...
# find_causal_relations: X = more seeds get caught in the fur of animals , Y = seed dispersal
#   Triples found: 1
#   Nodes visited: 2
#   Close hits: 0
#
# Step 3: Bridging and chain extraction...
#   Paths found: 1
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "more",
#   "confidence": "high",
#   "reasoning": "There is a single, short causal path (length 1) directly connecting 'more seeds get caught in the fur of animals' to increased 'seed dispersal'. This strongly suggests that more seeds getting caught in animal fur will lead to more seed dispersal.",
#   "scores": {
#     "more": 0.95,
#     "less": 0.02,
#     "no_effect": 0.03
#   },
#   "paths
#
# Prediction: more
# Gold: more
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 9/10
# ================================================================================
# Question: suppose more animals walk by plants happens, how will it affect MORE seed dispersal.
# Gold answer: more (A)
#
# Step 1: Extracting entities...
#   Cause: 'more animals walk by plants'
#   Outcome base: 'seed dispersal'
#
# Step 2: BFS expansion...
# find_causal_relations: X = more animals walk by plants , Y = seed dispersal
# is_same_variable: LLM 判定 seed consumption <-> seed dispersal = causal_but_separate
#   Triples found: 2
#   Nodes visited: 3
#   Close hits: 0
#
# Step 3: Bridging and chain extraction...
#   Paths found: 1
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "more",
#   "confidence": "high",
#   "reasoning": "There is a single, short path (length 1) from 'more animals walk by plants' to 'seed dispersal', and this path promotes seed dispersal. Removing the cause event would likely decrease seed dispersal.",
#   "scores": {
#     "more": 1.0,
#     "less": 0.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path
#
# Prediction: more
# Gold: more
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 10/10
# ================================================================================
# Question: suppose "heat doesnt make the connection to the boiler" happens, how will it affect heated water makes stem that turns a generator.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'heat doesnt make the connection to the boiler'
#   Outcome base: 'heated water making steam that turns a generator'
#
# Step 2: BFS expansion...
# find_causal_relations: X = heat doesnt make the connection to the boiler , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 heated water <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 steam <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = heated water , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 steam <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 increased temperature <-> heated water making steam that turns a generator = causal_but_separate
# find_causal_relations: X = steam , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 heat <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 pressure <-> heated water making steam that turns a generator = causal_but_separate
# find_causal_relations: X = increased temperature , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 water boiling <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 steam formation <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = heat , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 water temperature increase <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 steam generation <-> heated water making steam that turns a generator = identical
# find_causal_relations: X = pressure , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 boiling point <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 steam production <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = water boiling , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 steam production <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 temperature increase <-> heated water making steam that turns a generator = causal_but_separate
# find_causal_relations: X = steam formation , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 increased pressure <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 spinning turbine <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = water temperature increase , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 steam formation <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 generator pressure increase <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = steam generation , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 heated water <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 pressure increase <-> heated water making steam that turns a generator = causal_but_separate
# find_causal_relations: X = boiling point , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 water vapor <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 steam generation <-> heated water making steam that turns a generator = identical
# find_causal_relations: X = steam production , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 heated water <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 pressure increase <-> heated water making steam that turns a generator = causal_but_separate
# find_causal_relations: X = temperature increase , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 water heating <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 steam formation <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = increased pressure , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 boiling point decrease <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 water vaporization <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = spinning turbine , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 rotating shaft <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 mechanical energy <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = generator pressure increase , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 steam production <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 turbine rotation <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = pressure increase , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 boiler temperature rise <-> heated water making steam that turns a generator = causal_but_separate
# is_same_variable: LLM 判定 water boiling <-> heated water making steam that turns a generator = part_of
# find_causal_relations: X = water vapor , Y = heated water making steam that turns a generator
# is_same_variable: LLM 判定 steam <-> heated water making steam that turns a generator = part_of
# is_same_variable: LLM 判定 condensation <-> heated water making steam that turns a generator = causal_but_separate
#   Triples found: 36
#   Nodes visited: 26
#   Close hits: 24
#
# Step 3: Bridging and chain extraction...
#   Paths found: 22
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] No JSON braces found in LLM output. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "The cause event \"heat doesnt make the connection to the boiler\" directly suppresses the generation of heated water, which is a necessary precursor for steam production and ultimately turning the generator. All paths lead to the base outcome variable through suppression of heated water, suggesting a decrease in the likelihood of the base outcome.",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_effect": 0.0
#
# Prediction: less
# Gold: less
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 11/10
# ================================================================================
# Question: suppose greater volcanic eruption happens, how will it affect a SMALLER volcanic eruption.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'greater volcanic eruption happens'
#   Outcome base: 'volcanic eruption'
#
# Step 2: BFS expansion...
# find_causal_relations: X = greater volcanic eruption happens , Y = volcanic eruption
# is_same_variable: LLM 判定 magma flow <-> volcanic eruption = part_of
# is_same_variable: LLM 判定 ash cloud <-> volcanic eruption = part_of
# is_same_variable: LLM 判定 volcanic gases release <-> volcanic eruption = part_of
# find_causal_relations: X = magma flow , Y = volcanic eruption
# is_same_variable: LLM 判定 pressure buildup <-> volcanic eruption = part_of
# is_same_variable: LLM 判定 ground shaking <-> volcanic eruption = part_of
# find_causal_relations: X = ash cloud , Y = volcanic eruption
#   Triples found: 6
#   Nodes visited: 7
#   Close hits: 5
#
# Step 3: Bridging and chain extraction...
#   Paths found: 4
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] JSON parse failed after regex extraction. Raw output snippet:
# {
#   "effect_on_base": "more",
#   "confidence": "high",
#   "reasoning": "All four causal paths lead from a greater volcanic eruption to an increase in volcanic eruptions. The shortest path length is 2, indicating strong evidence.",
#   "scores": {
#     "more": 1.0,
#     "less": 0.0,
#     "no_effect": 0.0
#   },
#   "paths_eval": [
#     {
#       "path_id": 1,
#       "plausible":
#
# Prediction: less
# Gold: less
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 12/10
# ================================================================================
# Question: suppose less air in the nose happens, how will it affect GREATER transfer of oxygen to the body.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'less air in the nose happens'
#   Outcome base: 'transfer of oxygen to the body'
#
# Step 2: BFS expansion...
# find_causal_relations: X = less air in the nose happens , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen intake <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 lung function <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = oxygen intake , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 blood oxygen levels <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 lung function <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = lung function , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen uptake <-> transfer of oxygen to the body = identical
# is_same_variable: LLM 判定 blood oxygen levels <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = blood oxygen levels , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen binding to hemoglobin <-> transfer of oxygen to the body = part_of
# is_same_variable: LLM 判定 oxygen delivery to tissues <-> transfer of oxygen to the body = identical
# find_causal_relations: X = oxygen uptake , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 blood oxygen levels <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 cellular respiration <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = oxygen binding to hemoglobin , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 hemoglobin shape change <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 increased oxygen affinity <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = oxygen delivery to tissues , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 cellular respiration <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 energy production <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = cellular respiration , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 carbon dioxide production <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 oxygen consumption <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = hemoglobin shape change , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen binding <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = increased oxygen affinity , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen binding to hemoglobin <-> transfer of oxygen to the body = part_of
# is_same_variable: LLM 判定 reduced oxygen release in tissues <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = energy production , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 oxygen transport <-> transfer of oxygen to the body = identical
# is_same_variable: LLM 判定 cellular respiration <-> transfer of oxygen to the body = causal_but_separate
# find_causal_relations: X = carbon dioxide production , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 ocean acidification <-> transfer of oxygen to the body = unrelated
# is_same_variable: LLM 判定 increased greenhouse effect <-> transfer of oxygen to the body = unrelated
# find_causal_relations: X = oxygen consumption , Y = transfer of oxygen to the body
# is_same_variable: LLM 判定 blood oxygen levels <-> transfer of oxygen to the body = causal_but_separate
# is_same_variable: LLM 判定 cellular respiration <-> transfer of oxygen to the body = causal_but_separate
#   Triples found: 25
#   Nodes visited: 18
#   Close hits: 5
#
# Step 3: Bridging and chain extraction...
#   Paths found: 16
#
# Step 4: Generating description...
#
# Step 5: Final reasoning...
# [_final_llm_decision] No JSON braces found in LLM output. Raw output snippet:
# {
#   "effect_on_base": "less",
#   "confidence": "high",
#   "reasoning": "All causal paths from 'less air in the nose happens' to 'transfer of oxygen to the body' are positive (net_sign=1), meaning they promote oxygen transfer. However, the cause event itself suppresses these promoting factors (oxygen intake, lung function). Therefore, less air in the nose would likely decrease oxygen transfer.",
#   "scores": {
#     "more": 0.0,
#     "less": 1.0,
#     "no_
#
# Prediction: less
# Gold: less
# Result: ✓ CORRECT
#
# ================================================================================
# Processing datapoint 13/10
# ================================================================================
# Question: suppose less time needed happens, how will it affect HURTING the tire to be fixed.
# Gold answer: less (B)
#
# Step 1: Extracting entities...
#   Cause: 'less time needed happens'
#   Outcome base: 'tire being hurt during fixing'
#
# Step 2: BFS expansion...
# find_causal_relations: X = less time needed happens , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 careful tire handling <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 reduced force applied <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = careful tire handling , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 tire damage <-> tire being hurt during fixing = identical
# is_same_variable: LLM 判定 even pressure distribution <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = reduced force applied , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 less tire deformation <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 lower risk of puncture <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = tire damage , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 difficulty fixing <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 need for special tools <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = even pressure distribution , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 uniform tire contact <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 reduced stress concentration <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = less tire deformation , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 tire stress concentration <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 tire damage <-> tire being hurt during fixing = identical
# find_causal_relations: X = lower risk of puncture , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 tire damage during fixing <-> tire being hurt during fixing = identical
# find_causal_relations: X = difficulty fixing , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 force applied incorrectly <-> tire being hurt during fixing = causal_but_separate
# is_same_variable: LLM 判定 tire tools misused <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = need for special tools , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 tire damage risk <-> tire being hurt during fixing = identical
# is_same_variable: LLM 判定 improper installation <-> tire being hurt during fixing = causal_but_separate
# find_causal_relations: X = uniform tire contact , Y = tire being hurt during fixing
# is_same_variable: LLM 判定 even pressure distribution <-> tire being hurt during fixing = causal_but_separate
# ...
# ✓ [23] Gold: more       | Pred: more       | Conf: high
# ✓ [24] Gold: more       | Pred: more       | Conf: medium
# ✓ [25] Gold: less       | Pred: less       | Conf: high
# ✓ [26] Gold: more       | Pred: more       | Conf: medium
# ✓ [27] Gold: more       | Pred: more       | Conf: high
# ✗ [28] Gold: less       | Pred: more       | Conf: high
# ✓ [29] Gold: more       | Pred: more       | Conf: high
# ✓ [30] Gold: less       | Pred: less       | Conf: high
# ✓ [31] Gold: more       | Pred: more       | Conf: high
# ✓ [32] Gold: less       | Pred: less       | Conf: high
# ✗ [33] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [34] Gold: less       | Pred: less       | Conf: medium
# ✗ [35] Gold: less       | Pred: more       | Conf: high
# ✓ [36] Gold: less       | Pred: less       | Conf: high
# ✓ [37] Gold: more       | Pred: more       | Conf: high
# ✓ [38] Gold: less       | Pred: less       | Conf: high
# ✓ [39] Gold: more       | Pred: more       | Conf: high
# ✓ [40] Gold: less       | Pred: less       | Conf: high
# ✗ [41] Gold: more       | Pred: less       | Conf: high
# ✗ [42] Gold: more       | Pred: less       | Conf: high
# ✓ [43] Gold: more       | Pred: more       | Conf: high
# ✗ [44] Gold: less       | Pred: more       | Conf: high
# ✓ [45] Gold: less       | Pred: less       | Conf: high
# ✓ [46] Gold: less       | Pred: less       | Conf: medium
# ✓ [47] Gold: more       | Pred: more       | Conf: high
# ✓ [48] Gold: less       | Pred: less       | Conf: high
# ✗ [49] Gold: less       | Pred: more       | Conf: high
# ✗ [50] Gold: less       | Pred: more       | Conf: high
# ✓ [51] Gold: less       | Pred: less       | Conf: high
# ✓ [52] Gold: more       | Pred: more       | Conf: high
# ✓ [53] Gold: more       | Pred: more       | Conf: high
# ✓ [54] Gold: more       | Pred: more       | Conf: high
# ✗ [55] Gold: less       | Pred: more       | Conf: medium
# ✗ [56] Gold: less       | Pred: more       | Conf: high
# ✗ [57] Gold: less       | Pred: more       | Conf: high
# ✗ [58] Gold: less       | Pred: more       | Conf: high
# ✗ [59] Gold: less       | Pred: more       | Conf: high
# ✓ [60] Gold: less       | Pred: less       | Conf: medium
# ✓ [61] Gold: more       | Pred: more       | Conf: high
# ✓ [62] Gold: less       | Pred: less       | Conf: high
# ✗ [63] Gold: less       | Pred: more       | Conf: high
# ✗ [64] Gold: less       | Pred: more       | Conf: high
# ✓ [65] Gold: less       | Pred: less       | Conf: high
# ✓ [66] Gold: more       | Pred: more       | Conf: high
# ✗ [67] Gold: less       | Pred: more       | Conf: high
# ✗ [68] Gold: less       | Pred: more       | Conf: high
# ✗ [69] Gold: more       | Pred: less       | Conf: high
# ✓ [70] Gold: less       | Pred: less       | Conf: medium
# ✓ [71] Gold: more       | Pred: more       | Conf: high
# ✗ [72] Gold: less       | Pred: more       | Conf: medium
# ✓ [73] Gold: more       | Pred: more       | Conf: high
# ✓ [74] Gold: less       | Pred: less       | Conf: high
# ✓ [75] Gold: less       | Pred: less       | Conf: medium
# ✓ [76] Gold: less       | Pred: less       | Conf: high
# ✓ [77] Gold: less       | Pred: less       | Conf: high
# ✓ [78] Gold: less       | Pred: less       | Conf: high
# ✓ [79] Gold: more       | Pred: more       | Conf: high
# ✗ [80] Gold: more       | Pred: less       | Conf: medium
# ✓ [81] Gold: more       | Pred: more       | Conf: high
# ✗ [82] Gold: more       | Pred: less       | Conf: high
# ✗ [83] Gold: less       | Pred: more       | Conf: high
# ✓ [84] Gold: more       | Pred: more       | Conf: medium
# ✓ [85] Gold: less       | Pred: less       | Conf: high
# ✓ [86] Gold: less       | Pred: less       | Conf: medium
# ✓ [87] Gold: more       | Pred: more       | Conf: high
# ✓ [88] Gold: less       | Pred: less       | Conf: high
# ✗ [89] Gold: less       | Pred: more       | Conf: high
# ✓ [90] Gold: more       | Pred: more       | Conf: high
# ✓ [91] Gold: more       | Pred: more       | Conf: high
# ✓ [92] Gold: less       | Pred: less       | Conf: high
# ✓ [93] Gold: less       | Pred: less       | Conf: medium
# ✗ [94] Gold: more       | Pred: less       | Conf: high
# ✓ [95] Gold: less       | Pred: less       | Conf: high
# ✗ [96] Gold: less       | Pred: more       | Conf: high
# ✓ [97] Gold: more       | Pred: more       | Conf: high
# ✗ [98] Gold: less       | Pred: more       | Conf: medium
# ✓ [99] Gold: less       | Pred: less       | Conf: high
# ✗ [100] Gold: less       | Pred: more       | Conf: high
# ✓ [101] Gold: more       | Pred: more       | Conf: high
# ✓ [102] Gold: less       | Pred: less       | Conf: high
# ✓ [103] Gold: more       | Pred: more       | Conf: high
# ✗ [104] Gold: more       | Pred: less       | Conf: medium
# ✓ [105] Gold: more       | Pred: more       | Conf: high
# ✗ [106] Gold: less       | Pred: more       | Conf: medium
# ✗ [107] Gold: more       | Pred: less       | Conf: high
# ✗ [108] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [109] Gold: more       | Pred: more       | Conf: medium
# ✓ [110] Gold: less       | Pred: less       | Conf: high
# ✓ [111] Gold: less       | Pred: less       | Conf: high
# ✓ [112] Gold: more       | Pred: more       | Conf: high
# ✓ [113] Gold: more       | Pred: more       | Conf: high
# ✓ [114] Gold: less       | Pred: less       | Conf: medium
# ✗ [115] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [116] Gold: less       | Pred: less       | Conf: high
# ✗ [117] Gold: less       | Pred: more       | Conf: high
# ✓ [118] Gold: less       | Pred: less       | Conf: high
# ✓ [119] Gold: less       | Pred: less       | Conf: high
# ✓ [120] Gold: less       | Pred: less       | Conf: medium
# ✓ [121] Gold: more       | Pred: more       | Conf: high
# ✓ [122] Gold: more       | Pred: more       | Conf: high
# ✗ [123] Gold: less       | Pred: no_effect  | Conf: low
# ✗ [124] Gold: less       | Pred: more       | Conf: high
# ✗ [125] Gold: less       | Pred: more       | Conf: medium
# ✓ [126] Gold: less       | Pred: less       | Conf: medium
# ✓ [127] Gold: less       | Pred: less       | Conf: high
# ✗ [128] Gold: less       | Pred: more       | Conf: medium
# ✓ [129] Gold: less       | Pred: less       | Conf: high
# ✓ [130] Gold: more       | Pred: more       | Conf: high
# ✓ [131] Gold: more       | Pred: more       | Conf: high
# ✓ [132] Gold: more       | Pred: more       | Conf: high
# ✓ [133] Gold: more       | Pred: more       | Conf: high
# ✗ [134] Gold: more       | Pred: less       | Conf: high
# ✗ [135] Gold: more       | Pred: less       | Conf: medium
# ✓ [136] Gold: more       | Pred: more       | Conf: high
# ✓ [137] Gold: more       | Pred: more       | Conf: high
# ✓ [138] Gold: more       | Pred: more       | Conf: high
# ✓ [139] Gold: less       | Pred: less       | Conf: high
# ✓ [140] Gold: more       | Pred: more       | Conf: high
# ✓ [141] Gold: more       | Pred: more       | Conf: high
# ✓ [142] Gold: less       | Pred: less       | Conf: high
# ✓ [143] Gold: less       | Pred: less       | Conf: medium
# ✓ [144] Gold: less       | Pred: less       | Conf: high
# ✗ [145] Gold: less       | Pred: more       | Conf: high
# ✓ [146] Gold: less       | Pred: less       | Conf: high
# ✗ [147] Gold: more       | Pred: less       | Conf: high
# ✓ [148] Gold: less       | Pred: less       | Conf: high
# ✓ [149] Gold: less       | Pred: less       | Conf: high
# ✓ [150] Gold: more       | Pred: more       | Conf: high
# ✓ [151] Gold: more       | Pred: more       | Conf: high
# ✓ [152] Gold: less       | Pred: less       | Conf: high
# ✗ [153] Gold: less       | Pred: more       | Conf: medium
# ✓ [154] Gold: more       | Pred: more       | Conf: high
# ✓ [155] Gold: less       | Pred: less       | Conf: high
# ✓ [156] Gold: less       | Pred: less       | Conf: high
# ✗ [157] Gold: more       | Pred: less       | Conf: high
# ✓ [158] Gold: more       | Pred: more       | Conf: high
# ✓ [159] Gold: less       | Pred: less       | Conf: high
# ✗ [160] Gold: less       | Pred: more       | Conf: high
# ✓ [161] Gold: less       | Pred: less       | Conf: medium
# ✗ [162] Gold: less       | Pred: more       | Conf: high
# ✗ [163] Gold: less       | Pred: more       | Conf: high
# ✓ [164] Gold: more       | Pred: more       | Conf: high
# ✗ [165] Gold: less       | Pred: more       | Conf: high
# ✗ [166] Gold: less       | Pred: more       | Conf: high
# ✓ [167] Gold: more       | Pred: more       | Conf: high
# ✓ [168] Gold: less       | Pred: less       | Conf: medium
# ✓ [169] Gold: less       | Pred: less       | Conf: high
# ✗ [170] Gold: less       | Pred: more       | Conf: high
# ✓ [171] Gold: less       | Pred: less       | Conf: high
# ✓ [172] Gold: less       | Pred: less       | Conf: high
# ✓ [173] Gold: more       | Pred: more       | Conf: high
# ✓ [174] Gold: more       | Pred: more       | Conf: high
# ✓ [175] Gold: less       | Pred: less       | Conf: high
# ✓ [176] Gold: less       | Pred: less       | Conf: high
# ✓ [177] Gold: more       | Pred: more       | Conf: high
# ✓ [178] Gold: more       | Pred: more       | Conf: high
# ✗ [179] Gold: less       | Pred: more       | Conf: high
# ✗ [180] Gold: more       | Pred: less       | Conf: high
# ✓ [181] Gold: less       | Pred: less       | Conf: medium
# ✓ [182] Gold: less       | Pred: less       | Conf: high
# ✓ [183] Gold: more       | Pred: more       | Conf: high
# ✗ [184] Gold: less       | Pred: more       | Conf: high
# ✗ [185] Gold: less       | Pred: more       | Conf: high
# ✗ [186] Gold: less       | Pred: more       | Conf: high
# ✓ [187] Gold: less       | Pred: less       | Conf: high
# ✗ [188] Gold: less       | Pred: more       | Conf: high
# ✓ [189] Gold: more       | Pred: more       | Conf: high
# ✗ [190] Gold: more       | Pred: no_effect  | Conf: low
# ✓ [191] Gold: more       | Pred: more       | Conf: high
# ✓ [192] Gold: more       | Pred: more       | Conf: medium
# ✓ [193] Gold: less       | Pred: less       | Conf: high
# ✓ [194] Gold: less       | Pred: less       | Conf: high
# ✗ [195] Gold: less       | Pred: no_effect  | Conf: medium
# ✓ [196] Gold: less       | Pred: less       | Conf: high
# ✓ [197] Gold: more       | Pred: more       | Conf: high
# ✗ [198] Gold: more       | Pred: no_effect  | Conf: medium
# ✗ [199] Gold: less       | Pred: more       | Conf: high
# ✗ [200] Gold: less       | Pred: more       | Conf: high
# ✓ [201] Gold: less       | Pred: less       | Conf: high
# ✗ [202] Gold: less       | Pred: more       | Conf: high
# ✗ [203] Gold: less       | Pred: more       | Conf: medium
# ✗ [204] Gold: less       | Pred: more       | Conf: high
# ✗ [205] Gold: less       | Pred: more       | Conf: high
# ✗ [206] Gold: less       | Pred: more       | Conf: medium
# ✓ [207] Gold: less       | Pred: less       | Conf: high
# ✓ [208] Gold: less       | Pred: less       | Conf: high
# ✓ [209] Gold: more       | Pred: more       | Conf: high
# ✓ [210] Gold: less       | Pred: less       | Conf: high
# ✗ [211] Gold: less       | Pred: more       | Conf: medium
# ✓ [212] Gold: more       | Pred: more       | Conf: high
# ✗ [213] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [214] Gold: more       | Pred: more       | Conf: high
# ✗ [215] Gold: less       | Pred: more       | Conf: medium
# ✗ [216] Gold: less       | Pred: more       | Conf: high
# ✓ [217] Gold: less       | Pred: less       | Conf: high
# ✗ [218] Gold: less       | Pred: more       | Conf: medium
# ✓ [219] Gold: less       | Pred: less       | Conf: high
# ✓ [220] Gold: less       | Pred: less       | Conf: high
# ✓ [221] Gold: less       | Pred: less       | Conf: medium
# ✗ [222] Gold: less       | Pred: more       | Conf: high
# ✓ [223] Gold: less       | Pred: less       | Conf: high
# ✗ [224] Gold: less       | Pred: more       | Conf: high
# ✗ [225] Gold: more       | Pred: less       | Conf: high
# ✗ [226] Gold: less       | Pred: more       | Conf: high
# ✓ [227] Gold: less       | Pred: less       | Conf: medium
# ✓ [228] Gold: less       | Pred: less       | Conf: high
# ✓ [229] Gold: less       | Pred: less       | Conf: medium
# ✓ [230] Gold: less       | Pred: less       | Conf: high
# ✗ [231] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [232] Gold: more       | Pred: more       | Conf: high
# ✗ [233] Gold: less       | Pred: more       | Conf: high
# ✓ [234] Gold: more       | Pred: more       | Conf: high
# ✓ [235] Gold: less       | Pred: less       | Conf: high
# ✓ [236] Gold: more       | Pred: more       | Conf: high
# ✗ [237] Gold: less       | Pred: more       | Conf: high
# ✓ [238] Gold: less       | Pred: less       | Conf: high
# ✓ [239] Gold: less       | Pred: less       | Conf: medium
# ✓ [240] Gold: less       | Pred: less       | Conf: medium
# ✓ [241] Gold: more       | Pred: more       | Conf: high
# ✗ [242] Gold: less       | Pred: more       | Conf: high
# ✓ [243] Gold: more       | Pred: more       | Conf: high
# ✓ [244] Gold: less       | Pred: less       | Conf: high
# ✓ [245] Gold: more       | Pred: more       | Conf: high
# ✗ [246] Gold: less       | Pred: more       | Conf: high
# ✓ [247] Gold: more       | Pred: more       | Conf: high
# ✓ [248] Gold: less       | Pred: less       | Conf: high
# ✓ [249] Gold: more       | Pred: more       | Conf: medium
# ✓ [250] Gold: less       | Pred: less       | Conf: high
# ✗ [251] Gold: less       | Pred: more       | Conf: high
# ✓ [252] Gold: more       | Pred: more       | Conf: high
# ✗ [253] Gold: less       | Pred: more       | Conf: high
# ✓ [254] Gold: more       | Pred: more       | Conf: high
# ✓ [255] Gold: more       | Pred: more       | Conf: high
# ✓ [256] Gold: less       | Pred: less       | Conf: high
# ✓ [257] Gold: less       | Pred: less       | Conf: high
# ✓ [258] Gold: less       | Pred: less       | Conf: high
# ✓ [259] Gold: more       | Pred: more       | Conf: high
# ✓ [260] Gold: more       | Pred: more       | Conf: high
# ✓ [261] Gold: less       | Pred: less       | Conf: high
# ✓ [262] Gold: less       | Pred: less       | Conf: medium
# ✗ [263] Gold: less       | Pred: more       | Conf: high
# ✗ [264] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [265] Gold: more       | Pred: more       | Conf: high
# ✓ [266] Gold: more       | Pred: more       | Conf: high
# ✓ [267] Gold: more       | Pred: more       | Conf: high
# ✓ [268] Gold: more       | Pred: more       | Conf: high
# ✗ [269] Gold: less       | Pred: more       | Conf: medium
# ✓ [270] Gold: less       | Pred: less       | Conf: medium
# ✓ [271] Gold: less       | Pred: less       | Conf: high
# ✓ [272] Gold: more       | Pred: more       | Conf: high
# ✓ [273] Gold: more       | Pred: more       | Conf: high
# ✓ [274] Gold: less       | Pred: less       | Conf: high
# ✗ [275] Gold: less       | Pred: more       | Conf: high
# ✗ [276] Gold: less       | Pred: more       | Conf: high
# ✗ [277] Gold: more       | Pred: less       | Conf: high
# ✓ [278] Gold: more       | Pred: more       | Conf: high
# ✓ [279] Gold: more       | Pred: more       | Conf: high
# ✗ [280] Gold: less       | Pred: no_effect  | Conf: low
# ✓ [281] Gold: more       | Pred: more       | Conf: high
# ✗ [282] Gold: less       | Pred: no_effect  | Conf: medium
# ✗ [283] Gold: less       | Pred: more       | Conf: high
# ✓ [284] Gold: more       | Pred: more       | Conf: high
# ✓ [285] Gold: more       | Pred: more       | Conf: high
# ✗ [286] Gold: more       | Pred: less       | Conf: high
# ✓ [287] Gold: more       | Pred: more       | Conf: high
# ✓ [288] Gold: more       | Pred: more       | Conf: high
# ✓ [289] Gold: more       | Pred: more       | Conf: high
# ✓ [290] Gold: less       | Pred: less       | Conf: high
# ✓ [291] Gold: less       | Pred: less       | Conf: high
# ✗ [292] Gold: less       | Pred: more       | Conf: medium
# ✗ [293] Gold: less       | Pred: more       | Conf: medium
# ✗ [294] Gold: less       | Pred: more       | Conf: high
# ✓ [295] Gold: more       | Pred: more       | Conf: high
# ✓ [296] Gold: less       | Pred: less       | Conf: high
# ✓ [297] Gold: less       | Pred: less       | Conf: high
# ✓ [298] Gold: less       | Pred: less       | Conf: medium
# ✗ [299] Gold: less       | Pred: more       | Conf: high
# ✓ [300] Gold: more       | Pred: more       | Conf: high
# --------------------------------------------------------------------------------
#
# Results saved to: single_question_demo_results.json
