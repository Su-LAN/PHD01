# %%
import json
from pathlib import Path

path = Path("Dataset/causenet-precision.jsonl")

SAMPLE_N = 3

data = []
with path.open("r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        if i >= SAMPLE_N:
            break
        data.append(json.loads(line))

# %%
data[0]
# Out:
# {'causal_relation': {'cause': {'concept': 'accident'},
#   'effect': {'concept': 'death'}},
#  'sources': [{'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '45710',
#     'wikipedia_page_title': 'Forensic science',
#     'wikipedia_revision_id': '861543252',
#     'wikipedia_revision_timestamp': '2018-09-28T06:01:51Z',
#     'sentence_section_heading': 'Origins of forensic science and early methods',
#     'sentence_section_level': '3',
#     'sentence': 'For example, the book also described how to distinguish between a drowning (water in the lungs) and strangulation (broken neck cartilage), along with other evidence from examining corpses on determining if a death was caused by murder, suicide or an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:agent\tcaused/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '124363',
#     'wikipedia_page_title': 'Goodsprings, Nevada',
#     'wikipedia_revision_id': '857283240',
#     'wikipedia_revision_timestamp': '2018-08-30T18:53:11Z',
#     'sentence_section_heading': 'History',
#     'sentence_section_level': '2',
#     'sentence': 'The accident resulted in her death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '203292',
#     'wikipedia_page_title': 'Léon Gambetta',
#     'wikipedia_revision_id': '860698712',
#     'wikipedia_revision_timestamp': '2018-09-22T13:06:06Z',
#     'sentence_section_heading': 'Personal life',
#     'sentence_section_level': '2',
#     'sentence': 'It seems she had just consented to become his wife, and the date of the marriage had been fixed, when the accident which caused his death occurred in her presence.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '290356',
#     'wikipedia_page_title': 'Accidental death and dismemberment insurance',
#     'wikipedia_revision_id': '799599582',
#     'wikipedia_revision_timestamp': '2017-09-08T18:06:45Z',
#     'sentence_section_heading': 'Accidental death and dismemberment insurance',
#     'sentence_section_level': '1',
#     'sentence': 'In insurance, accidental death and dismemberment (AD&D) is a policy that pays benefits to the beneficiary if the cause of death is an accident.',
#     'path_pattern': '[[cause]]/N\t+nsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '331731',
#     'wikipedia_page_title': 'Plaster',
#     'wikipedia_revision_id': '861392739',
#     'wikipedia_revision_timestamp': '2018-09-27T02:50:03Z',
#     'sentence_section_heading': 'Funeral processes',
#     'sentence_section_level': '3',
#     'sentence': 'Plaster is used by many morticians and funeral home directors to recreate destroyed tissue, reconnect severed limbs to corpses, and to fill wounds sustained during the accident or murder that caused the death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '573279',
#     'wikipedia_page_title': 'Karen Silkwood',
#     'wikipedia_revision_id': '860539374',
#     'wikipedia_revision_timestamp': '2018-09-21T10:43:00Z',
#     'sentence_section_heading': 'Death',
#     'sentence_section_level': '2',
#     'sentence': "Some journalists have theorized that Silkwood's car was rammed from behind by another vehicle, with the intent to cause an accident that would result in her death.",
#     'path_pattern': '[[cause]]/N\t-nsubj\tresult/VB\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '1370912',
#     'wikipedia_page_title': 'Graniteville train crash',
#     'wikipedia_revision_id': '853398737',
#     'wikipedia_revision_timestamp': '2018-08-04T14:14:25Z',
#     'sentence_section_heading': 'Victims',
#     'sentence_section_level': '2',
#     'sentence': 'On April 21, 2005, one more death was attributed to the accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tattributed/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '3008883',
#     'wikipedia_page_title': 'Second Sahrawi Intifada',
#     'wikipedia_revision_id': '846449003',
#     'wikipedia_revision_timestamp': '2018-06-18T21:11:09Z',
#     'sentence_section_heading': 'Demonstrations and arrests',
#     'sentence_section_level': '2',
#     'sentence': 'On 30 October 2005, a first fatality was recorded when 31-year-old Hamdi Lembarki died after what human rights organizations assured was police brutality during his arrest, although at first Moroccan authorities attributed his death to an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tattributed/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '3136942',
#     'wikipedia_page_title': 'Caroline Kirkland',
#     'wikipedia_revision_id': '817703200',
#     'wikipedia_revision_timestamp': '2017-12-30T02:09:53Z',
#     'sentence_section_heading': 'Biography',
#     'sentence_section_level': '2',
#     'sentence': 'In 1846 an accident resulted in his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '3720331',
#     'wikipedia_page_title': 'Innocent Drinks',
#     'wikipedia_revision_id': '859243838',
#     'wikipedia_revision_timestamp': '2018-09-12T18:55:23Z',
#     'sentence_section_heading': 'Health and Safety',
#     'sentence_section_level': '3',
#     'sentence': 'Gavin Bedford had been dismantling machinery at the plant when he was struck by falling pipework, an accident which resulted in his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '4215449',
#     'wikipedia_page_title': 'Mic Christopher',
#     'wikipedia_revision_id': '841195557',
#     'wikipedia_revision_timestamp': '2018-05-14T15:18:52Z',
#     'sentence_section_heading': 'Death',
#     'sentence_section_level': '2',
#     'sentence': 'The accident that caused his death was described by friend Glen Hansard: "He went for a few beers after the show and simply slipped on some steps.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '4424771',
#     'wikipedia_page_title': 'Point system (driving)',
#     'wikipedia_revision_id': '859459526',
#     'wikipedia_revision_timestamp': '2018-09-14T05:31:41Z',
#     'sentence_section_heading': 'Netherlands',
#     'sentence_section_level': '4',
#     'sentence': 'Drivers can get a point for:\\n\\n Dangerous behaviour in traffic,\\n Causing an accident resulting in death or injury\\n Tailgating\\n Exceeding the speedlimit with more than 40\xa0km/h (motorways), or 30\xa0km/h  (all other roads)\\n Any violation of the law which resulted in injury or damage\\nSome of these violations could also directly result in loss of the licence, however when a driver has 2 points the licence is automatically revoked and a driving test has to be passed again, whereas normally the violation would only result in the licence being suspended for several months.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '4424771',
#     'wikipedia_page_title': 'Point system (driving)',
#     'wikipedia_revision_id': '859459526',
#     'wikipedia_revision_timestamp': '2018-09-14T05:31:41Z',
#     'sentence_section_heading': 'Arizona',
#     'sentence_section_level': '5',
#     'sentence': 'Offenses that lead to this are the following:\\n\\n DUI (blood alcohol concentration (BAC of 0.08% or higher): 8 points\\n Extreme DUI: 8 points\\n Reckless driving: 8 points\\n Aggressive driving: 8 points\\n Leaving the scene of an accident: 6 points\\n Running a stop sign or traffic signal or failing to yield, accident causing death: 6 points\\n Running a stop sign or traffic signal or failing to yield, accident causing serious injury: 4 points\\n Speeding: 3 points\\n Driving or parking over area where one or more lanes diverge to go in different directions (gore area): 3 points\\n All other driving violations: 2 points\\n\\nThere are other offenses that can count toward this (e.g. HOV lane misuse is a 3-point offense)',
#     'path_pattern': '[[cause]]/N\t+acl\tcausing/VBG\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '4848759',
#     'wikipedia_page_title': 'William Hume Blake',
#     'wikipedia_revision_id': '857402712',
#     'wikipedia_revision_timestamp': '2018-08-31T13:22:22Z',
#     'sentence_section_heading': 'Family',
#     'sentence_section_level': '2',
#     'sentence': 'Her death on February 3, 1886, resulted from an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:from\tresulted/VBD\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '5761492',
#     'wikipedia_page_title': 'Jane Bunford',
#     'wikipedia_revision_id': '847071887',
#     'wikipedia_revision_timestamp': '2018-06-22T18:42:15Z',
#     'sentence_section_heading': 'Accident',
#     'sentence_section_level': '2',
#     'sentence': 'The accident also indirectly led to her death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tled/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '5935959',
#     'wikipedia_page_title': 'Tom Williams (ice hockey, born 1940)',
#     'wikipedia_revision_id': '845979660',
#     'wikipedia_revision_timestamp': '2018-06-15T13:05:08Z',
#     'sentence_section_heading': 'Personal life',
#     'sentence_section_level': '2',
#     'sentence': 'In November 1970 his wife died suddenly and it was never determined for certain whether her death was due to accident or suicide.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '6391816',
#     'wikipedia_page_title': 'Parveen Shakir',
#     'wikipedia_revision_id': '843490867',
#     'wikipedia_revision_timestamp': '2018-05-29T13:53:58Z',
#     'sentence_section_heading': 'Family and death',
#     'sentence_section_level': '3',
#     'sentence': 'The accident resulted in her death, a great loss to the Urdu poetry world.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '7256012',
#     'wikipedia_page_title': 'Helene Chadwick',
#     'wikipedia_revision_id': '854679301',
#     'wikipedia_revision_timestamp': '2018-08-13T02:07:44Z',
#     'sentence_section_heading': 'Personal life and death',
#     'sentence_section_level': '2',
#     'sentence': 'Her death was indirectly the result of an accident she suffered in June 1939.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '8290216',
#     'wikipedia_page_title': 'Kirknewton, West Lothian',
#     'wikipedia_revision_id': '821141802',
#     'wikipedia_revision_timestamp': '2018-01-18T17:26:40Z',
#     'sentence_section_heading': 'The village',
#     'sentence_section_level': '2',
#     'sentence': 'One accident involving a motor vehicle led to a death and another involving a pedestrian had tragic consequences but the victim did survive.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tled/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '9564343',
#     'wikipedia_page_title': 'Peter Beckford',
#     'wikipedia_revision_id': '858581001',
#     'wikipedia_revision_timestamp': '2018-09-08T05:58:30Z',
#     'sentence_section_heading': 'Family and legacy',
#     'sentence_section_level': '2',
#     'sentence': 'His death resulted from an accident when he rushed to the defense of his son, who had caused such a commotion in the House of Assembly that swords were drawn.',
#     'path_pattern': '[[cause]]/N\t-nmod:from\tresulted/VBD\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '9854251',
#     'wikipedia_page_title': 'Allegheny County Police Department',
#     'wikipedia_revision_id': '842791439',
#     'wikipedia_revision_timestamp': '2018-05-24T17:52:25Z',
#     'sentence_section_heading': 'Legal authority',
#     'sentence_section_level': '2',
#     'sentence': 'In cases of offenses for violation of any of the provisions of the Vehicle Code, the power to make arrests without warrant shall be limited to cases where the offense is designated a felony or a misdemeanor, and cases causing or contributing to an accident resulting in injury or death to any person.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '10219581',
#     'wikipedia_page_title': 'Expatriate insurance',
#     'wikipedia_revision_id': '841085103',
#     'wikipedia_revision_timestamp': '2018-05-14T00:16:45Z',
#     'sentence_section_heading': 'Expatriate international auto insurance',
#     'sentence_section_level': '2',
#     'sentence': 'ACT insurance will only cover the insured for any death or injury resulting from an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:from\tresulting/VBG\t-acl\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '11097865',
#     'wikipedia_page_title': 'Venture to the Moon',
#     'wikipedia_revision_id': '861276522',
#     'wikipedia_revision_timestamp': '2018-09-26T08:51:19Z',
#     'sentence_section_heading': 'Plot summary',
#     'sentence_section_level': '2',
#     'sentence': '"Green Fingers" describes how a Russian team member - a botanist - secretly engineers plant life that could survive on the Moon\'s surface, and the accident that causes his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcauses/VBZ\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '13615954',
#     'wikipedia_page_title': 'Robert F. Swinnie Airport',
#     'wikipedia_revision_id': '544988678',
#     'wikipedia_revision_timestamp': '2013-03-17T16:26:05Z',
#     'sentence_section_heading': 'Facilities and aircraft',
#     'sentence_section_level': '2',
#     'sentence': 'This caused an accident leading to death in early 2011.',
#     'path_pattern': '[[cause]]/N\t+acl\tleading/VBG\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '16872918',
#     'wikipedia_page_title': 'John William Pitt Kinau',
#     'wikipedia_revision_id': '855980831',
#     'wikipedia_revision_timestamp': '2018-08-22T03:54:43Z',
#     'sentence_section_heading': 'Death and burial',
#     'sentence_section_level': '2',
#     'sentence': 'The cause of his death was said to be an accident, although the details are unknown.',
#     'path_pattern': '[[cause]]/N\t+nsubj:xsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '25153936',
#     'wikipedia_page_title': 'Performance-based building design',
#     'wikipedia_revision_id': '831176544',
#     'wikipedia_revision_timestamp': '2018-03-19T05:14:08Z',
#     'sentence_section_heading': 'Performance approach and prescriptive approach',
#     'sentence_section_level': '3',
#     'sentence': 'The content of prescriptive codes and standards is usually a consequence of an accident causing injury or death which requires a remedy to avoid a repeat, as a consequence of some hazardous situation, or as a consequence of some recognized social need.',
#     'path_pattern': '[[cause]]/N\t+acl\tcausing/VBG\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '25361786',
#     'wikipedia_page_title': 'William V. Wheeler',
#     'wikipedia_revision_id': '848630679',
#     'wikipedia_revision_timestamp': '2018-07-03T06:31:42Z',
#     'sentence_section_heading': 'Early Life and the Wheeler Family',
#     'sentence_section_level': '2',
#     'sentence': 'An accident caused Elizabeth Wheeler’s death in 1851 and Walter remarried Mary P. Stanley in 1853.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '27458681',
#     'wikipedia_page_title': 'Carl Ferdinand Appun',
#     'wikipedia_revision_id': '778950809',
#     'wikipedia_revision_timestamp': '2017-05-06T04:30:12Z',
#     'sentence_section_heading': 'Carl Ferdinand Appun',
#     'sentence_section_level': '1',
#     'sentence': 'In 1871 he undertook a second  exploration of  Guyana, where he had an accident which led to his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tled/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '27883627',
#     'wikipedia_page_title': 'Illegals Program',
#     'wikipedia_revision_id': '860349544',
#     'wikipedia_revision_timestamp': '2018-09-20T01:56:01Z',
#     'sentence_section_heading': 'FBI arrests and criminal charges',
#     'sentence_section_level': '2',
#     'sentence': "A Florida medical examiner's report, released on September 20, 2010, cited an accident and a tumour as the cause of death.",
#     'path_pattern': '[[cause]]/N\t+nmod:as\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '31566384',
#     'wikipedia_page_title': 'Antoni Gaudí',
#     'wikipedia_revision_id': '860989877',
#     'wikipedia_revision_timestamp': '2018-09-24T12:45:48Z',
#     'sentence_section_heading': 'Personal life',
#     'sentence_section_level': '3',
#     'sentence': 'The older Gaudí ate frugally, dressed in old, worn-out suits, and neglected his appearance to the extent that sometimes he was taken for a beggar, such as after the accident that caused his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '33637770',
#     'wikipedia_page_title': 'Mary Beth Harshbarger',
#     'wikipedia_revision_id': '827668346',
#     'wikipedia_revision_timestamp': '2018-02-26T01:23:31Z',
#     'sentence_section_heading': 'Trial',
#     'sentence_section_level': '2',
#     'sentence': 'Justice Richard LeBlanc concluded that the Crown had failed to prove Harshbarger displayed a complete disregard for the safety of others, and that the death was “a result of an accident and nothing more”.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '34491580',
#     'wikipedia_page_title': 'John C. Chase',
#     'wikipedia_revision_id': '856587720',
#     'wikipedia_revision_timestamp': '2018-08-26T08:11:41Z',
#     'sentence_section_heading': 'Early years',
#     'sentence_section_level': '3',
#     'sentence': 'When John was just 1 year old the family moved to the small town of Ossipee, where his father Levi M. Chase met with an accident that caused his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '38706705',
#     'wikipedia_page_title': 'July 1964',
#     'wikipedia_revision_id': '855486735',
#     'wikipedia_revision_timestamp': '2018-08-18T17:30:50Z',
#     'sentence_section_heading': 'July 21, 1964 (Tuesday)',
#     'sentence_section_level': '2',
#     'sentence': "His Walther 9mm pistol was found by his side, along with a spent cartridge; a coroner's inquest concluded that the cause of death was an accident resulting from falling while carrying a loaded weapon, rather than a suicide or a homicide.",
#     'path_pattern': '[[cause]]/N\t+nsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '43083115',
#     'wikipedia_page_title': 'Heroes of the Eastern Skies',
#     'wikipedia_revision_id': '807147693',
#     'wikipedia_revision_timestamp': '2017-10-26T05:37:33Z',
#     'sentence_section_heading': 'Cast',
#     'sentence_section_level': '2',
#     'sentence': '(In actual history, his death was due to an accident while flying to Taiyuan city to assume command of the 28th Pursuit Group from wounded Captain Chan Kee-Wong.)',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '45083774',
#     'wikipedia_page_title': 'Bill Denny',
#     'wikipedia_revision_id': '849785225',
#     'wikipedia_revision_timestamp': '2018-07-11T09:51:47Z',
#     'sentence_section_heading': 'Later life',
#     'sentence_section_level': '2',
#     'sentence': 'Reverend Denny suffered from an illness that resulted from the accident which contributed to his death in June 1941.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcontributed/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '46298078',
#     'wikipedia_page_title': 'Chris Soules',
#     'wikipedia_revision_id': '861194325',
#     'wikipedia_revision_timestamp': '2018-09-25T19:14:39Z',
#     'sentence_section_heading': 'Personal life',
#     'sentence_section_level': '2',
#     'sentence': 'Chris was charged with a class D felony for leaving the scene of an accident causing death.',
#     'path_pattern': '[[cause]]/N\t+acl\tcausing/VBG\t+dobj\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '49273972',
#     'wikipedia_page_title': 'Alt-right',
#     'wikipedia_revision_id': '861419333',
#     'wikipedia_revision_timestamp': '2018-09-27T08:31:55Z',
#     'sentence_section_heading': 'Unite the Right rally',
#     'sentence_section_level': '4',
#     'sentence': 'Fields was charged with second-degree murder, three counts of malicious wounding and failure to stop following an accident resulting in death and held without bail.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '53114406',
#     'wikipedia_page_title': 'Auchincruive Waggonway',
#     'wikipedia_revision_id': '811021120',
#     'wikipedia_revision_timestamp': '2017-11-19T01:05:46Z',
#     'sentence_section_heading': 'Operation of the Waggonway',
#     'sentence_section_level': '3',
#     'sentence': 'The use of steam locomotives is recorded and by 1860 they were use with the record of a death caused by an accident involving a locomotive returning from Annbank in 1865.',
#     'path_pattern': '[[cause]]/N\t-nmod:by\tcaused/VBN\t-acl\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '54794956',
#     'wikipedia_page_title': 'Unite the Right rally',
#     'wikipedia_revision_id': '861756991',
#     'wikipedia_revision_timestamp': '2018-09-29T20:00:38Z',
#     'sentence_section_heading': 'Prosecution',
#     'sentence_section_level': '3',
#     'sentence': 'Fields was charged with second-degree murder, three counts of malicious wounding and failure to stop following an accident resulting in death, and held without bail.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'wikipedia_sentence',
#    'payload': {'wikipedia_page_id': '57186404',
#     'wikipedia_page_title': 'Júlio Delamare',
#     'wikipedia_revision_id': '837477027',
#     'wikipedia_revision_timestamp': '2018-04-21T02:28:58Z',
#     'sentence_section_heading': 'Júlio Delamare',
#     'sentence_section_level': '1',
#     'sentence': 'The Júlio Delamare Aquatics Centre, situated in Rio de Janeiro, was named after him, five years after the accident that caused his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:6689aeaa-9dd5-42e5-851f-93557f796cd7',
#     'clueweb12_page_reference': 'http://alcor.org/printable.cgi?fname=Library%2Fhtml%2Freligionandcryonics.html',
#     'clueweb12_page_timestamp': '2012-02-22T05:10:24Z',
#     'sentence': 'It seems that all death can be attributed either to disease or accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tattributed/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:b20fda4e-1d5d-4c92-b37b-7953d90bd1a3',
#     'clueweb12_page_reference': 'http://5ones.com/category/snow/',
#     'clueweb12_page_timestamp': '2012-02-22T16:51:20Z',
#     'sentence': 'Granted, now people have a face to associate to an accident that resulted in a death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:cfa238bb-9077-44ff-a6bd-0a3c0695c985',
#     'clueweb12_page_reference': 'http://www.santaclararesearch.net/SCBIOS/wzangney.html',
#     'clueweb12_page_timestamp': '2012-02-18T23:58:08Z',
#     'sentence': 'His death, which occurred at Boston, was the result of an accident, he having been killed by the firing of a gun which was intended as a salute to a ship belonging to him, which was coming into the harbor.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:11403439-dac9-4b46-86fa-528bb62903b9',
#     'clueweb12_page_reference': 'http://www.tickethelpline.com/lawyer-attorney-1113032.html',
#     'clueweb12_page_timestamp': '2012-02-18T23:59:40Z',
#     'sentence': '(a) The driver of any vehicle, knowingly involved in an accident resulting in injury or death to any person shall immediately stop the vehicle at the scene of the accident or as close thereto as possible but shall then forthwith return to and in every event shall remain at the scene until he has fulfilled the requirements of subsection (c) of this section.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:11403439-dac9-4b46-86fa-528bb62903b9',
#     'clueweb12_page_reference': 'http://www.tickethelpline.com/lawyer-attorney-1113032.html',
#     'clueweb12_page_timestamp': '2012-02-18T23:59:40Z',
#     'sentence': 'The term of imprisonment required by this subsection shall be imposed only if the accident resulted in death or injury to a person other than the driver convicted of violating this section.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:11403439-dac9-4b46-86fa-528bb62903b9',
#     'clueweb12_page_reference': 'http://www.tickethelpline.com/lawyer-attorney-1113032.html',
#     'clueweb12_page_timestamp': '2012-02-18T23:59:40Z',
#     'sentence': "(c) The driver of any vehicle knowingly involved in an accident resulting in injury or death to any person or damage to any vehicle or property shall give his name and address and exhibit his operator's license and registration certificate of his vehicle to the person injured or whose vehicle or property was damaged and to any police officer or witness of the accident, and to the driver or occupants of the vehicle collided with and render to a person injured in the accident reasonable assistance, including the carrying of that person to a hospital or a physician for medical or surgical treatment, if it is apparent that the treatment is necessary or is requested by the injured person.",
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c5f7d055-351e-4835-b33d-5ac9f2fa5ae0',
#     'clueweb12_page_reference': 'http://www.our-articles.com/Recreation_and_Sports/Boating/article-752.html',
#     'clueweb12_page_timestamp': '2012-02-19T21:00:23Z',
#     'sentence': 'The case is required to be reported to the federal or state authorities especially when following circumstances happen: the accident causes the death or disappearance, indicating death or injury, of any individual; the boat accident caused injuries to the persons in it and requires medical care beyond first aid and/or if damages to the vessel or property exceeds five hundred dollars.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcauses/VBZ\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:1ad9ba9f-c8b6-4240-8fcf-259be2ff9421',
#     'clueweb12_page_reference': 'http://www.weststockbridge-ma.gov/Pages/WestStockbridgeMA_Police/how%20to%20report',
#     'clueweb12_page_timestamp': '2012-02-20T08:29:04Z',
#     'sentence': "Within five days of the accident, you will need to file an Commonwealth of Massachusetts Operator's Accident Report when the accident results in personal injury or death, when property damage exceeds $1,000, when one of the vehicles involved has fled the scene, or when you have any doubt as to the above.",
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:2ee134cb-c991-42d6-b5e6-38fdc1d6d522',
#     'clueweb12_page_reference': 'http://www.scotcourts.gov.uk/opinions/mcintosh.html',
#     'clueweb12_page_timestamp': '2012-02-20T06:08:07Z',
#     'sentence': 'In my view it is reasonable and consistent with all of the evidence led to conclude that the accident which resulted in the death was that capsize.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:04850003-cdf8-43f1-ae32-9f1aa6976872',
#     'clueweb12_page_reference': 'http://www.srgw.demon.co.uk/CremSoc3/StatutoryLaw/Reg40-30.html',
#     'clueweb12_page_timestamp': '2012-02-19T05:30:42Z',
#     'sentence': '(d) An inquest has been held and a certificate has been given by the Coroner in Form "E"; provided that in any case in which the death occurs in connection with an industrial, railway, flying or road accident and the Coroner adjourns the inquest with a view to the investigation of the causes of the accident, he may give a certificate in Form "E" with the necessary modifications if he is satisfied that the death was due to an accident, without waiting for the termination of the inquest.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c918dc0b-4b10-4d51-9dcb-9383277ab69c',
#     'clueweb12_page_reference': 'http://www.vietnam.embassy.gov.au/hnoi/Driving%5fin%5fVietnam.html',
#     'clueweb12_page_timestamp': '2012-02-20T03:33:16Z',
#     'sentence': 'Experience has shown that such penalties might be as much as a three year jail sentence for driving unlicensed, up to ten years imprisonment for driving unlicensed and causing an accident, and up to twenty years imprisonment for driving unlicensed and causing an accident resulting in death.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:1055daac-998c-4177-820f-e154e871862f',
#     'clueweb12_page_reference': 'http://www.vietnam.embassy.gov.au/hnoi/Driving_in_Vietnam.html',
#     'clueweb12_page_timestamp': '2012-02-20T02:56:49Z',
#     'sentence': 'Experience has shown that such penalties might be as much as a three year jail sentence for driving unlicensed, up to ten years imprisonment for driving unlicensed and causing an accident, and up to twenty years imprisonment for driving unlicensed and causing an accident resulting in death.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:7eca7260-2f6d-4795-87cc-f17734abdad0',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving/course-eligibility/',
#     'clueweb12_page_timestamp': '2012-02-22T04:45:02Z',
#     'sentence': 'Your ticket cannot be associated with an accident that caused a death or serious injury.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:5f4a9b0b-2074-431b-840a-399f1aa38152',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving/course-information/',
#     'clueweb12_page_timestamp': '2012-02-22T04:42:59Z',
#     'sentence': 'You could be ordered to attend traffic survival school if you have 8-12 Arizona driving points on your license in the last year, are convicted of aggressive driving, caused an accident resulting in serious injury or death, received multiple moving violations within a year under the age of 18, or are caught running a red light.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:24921531-f9e7-417b-81cf-e52d4ede86e3',
#     'clueweb12_page_reference': 'http://champaign.ilgenweb.net/biographies/bio0413.html',
#     'clueweb12_page_timestamp': '2012-02-23T02:18:21Z',
#     'sentence': 'His death was caused by an accident, which took place at his father\x92s homestead in this county while he was in Pesotum Township on business.',
#     'path_pattern': '[[cause]]/N\t-nmod:agent\tcaused/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:98dc5284-f1cf-4e0e-8588-31a37170f05c',
#     'clueweb12_page_reference': 'http://www.agcsc.org/Page.asp?n=33614&snid=jMNC%5B7M%3E%5B&org=agcsc.org',
#     'clueweb12_page_timestamp': '2012-02-25T01:27:21Z',
#     'sentence': 'I hereby release, waive and discharge the AGCSC and each of its members from any and all liability due to any accident resulting in death or injury, or personal property damage sustained as a participant in the activities of the AGCSC.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:4747421c-485e-4856-a625-c0cd9f75a751',
#     'clueweb12_page_reference': 'http://articlesmart.org/Article/10148/Car-Crash-Lawyer-Los-Angeles-Offers-Extensive-Support-With-Modern-Mechanisms.html',
#     'clueweb12_page_timestamp': '2012-02-24T00:32:38Z',
#     'sentence': 'One can also avail this service even if two years have been lapsed since the accident resulting in injury or death.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:86d02e2f-5c06-4c6c-bf5b-d76d2df458c8',
#     'clueweb12_page_reference': 'http://www.taiwandc.org/twcom/65-no7.htm',
#     'clueweb12_page_timestamp': '2012-02-19T13:13:38Z',
#     'sentence': 'The authorities claimed his death was a result of an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:635e907b-2344-48d2-96b9-441ee0c06e81',
#     'clueweb12_page_reference': 'http://italy.usembassy.gov/acs/emergency/emergency-crime.html',
#     'clueweb12_page_timestamp': '2012-02-22T21:32:13Z',
#     'sentence': 'If the accident resulted in death, the application for financial compensation may be filed within ten years of the accident’s occurrence.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:55a4aa06-13a5-4136-9572-5a22bdbd894a',
#     'clueweb12_page_reference': 'http://labor.state.ny.us/workerprotection/safetyhealth/sh14.shtm',
#     'clueweb12_page_timestamp': '2012-02-24T02:56:59Z',
#     'sentence': 'If the accident results in death to a person or persons, or results in property damage in excess of $25,000, the report shall be given immediately by telephone, and confirmed by registered mail within 24 hours.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:7c0c0e91-c75e-4a13-b88e-9799e91392b1',
#     'clueweb12_page_reference': 'http://www.w3aeiou.org/auto-insurance-law-in-california.htm',
#     'clueweb12_page_timestamp': '2012-02-19T06:55:42Z',
#     'sentence': 'You should also report to the police if the accident has caused death or serious wound.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBN\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:fda4ffb4-6fa8-47ac-8c4a-c6e7c926c217',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving/',
#     'clueweb12_page_timestamp': '2012-02-22T02:26:24Z',
#     'sentence': 'You could be ordered to attend traffic survival school if you have 8-12 Arizona driving points on your license in the last year, are convicted of aggressive driving, caused an accident resulting in serious injury or death, received multiple moving violations within a year under the age of 18, or are caught running a red light.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:fda4ffb4-6fa8-47ac-8c4a-c6e7c926c217',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving/',
#     'clueweb12_page_timestamp': '2012-02-22T02:26:24Z',
#     'sentence': 'Your ticket cannot be associated with an accident that caused a death or serious injury.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:faf8924d-e164-4f57-9222-94fe5e44f836',
#     'clueweb12_page_reference': 'http://www.njatty.com/blog/2011/04/',
#     'clueweb12_page_timestamp': '2012-02-19T03:29:41Z',
#     'sentence': 'In this particular story, if the woman had caused an accident that resulted in injury or death, she could have faced serious criminal penalties and civil liability.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c50818eb-c4dd-497f-b8e2-e630e0c0aafb',
#     'clueweb12_page_reference': 'http://www.vermontjudiciary.org/GTC/judicial/FAQs.aspx',
#     'clueweb12_page_timestamp': '2012-02-20T19:01:42Z',
#     'sentence': 'When operating a commercial vehicle, serious traffic violations include speeding 15 mph or more over the speed limit, driving in a careless and negligent or reckless manner, changing lanes improperly, following too closely, and violating traffic control laws in connection with an accident resulting in death.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:6d3bcac0-2aae-45b8-b5ec-e0d931ca7ab0',
#     'clueweb12_page_reference': 'http://www.usroads.com/journals/rilj/9912/ri991203.htm',
#     'clueweb12_page_timestamp': '2012-02-20T12:25:04Z',
#     'sentence': "Taylor's driver's license was suspended for ninety days on the grounds that he had caused an accident resulting in death and had committed a serious violation of the motor vehicle laws.",
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:a6c6504d-a479-49b6-8471-21962602f576',
#     'clueweb12_page_reference': 'http://www.smartautoinsurance.com/alaska-auto-insurance.html',
#     'clueweb12_page_timestamp': '2012-02-20T04:30:45Z',
#     'sentence': 'Should you be involved in an accident that results in bodily injury, death, or property damage exceeding $501, you will be required to provide proof of Alaska auto insurance.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:92746160-9826-4355-b8b2-0f161ad0c067',
#     'clueweb12_page_reference': 'http://www.robertreeveslaw.com/locations/inland-empire/riverside-personal-injury-lawyer.html',
#     'clueweb12_page_timestamp': '2012-02-18T23:38:10Z',
#     'sentence': 'While life in Riverside may seem ideal, an accident resulting in death or serious injury can happen at any time.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:3243172d-09f1-42db-8f21-cf9e5bb9e704',
#     'clueweb12_page_reference': 'http://www.swarb.co.uk/lisc/HelPr19921992.php',
#     'clueweb12_page_timestamp': '2012-02-19T15:39:31Z',
#     'sentence': 'The true cause of the death was the accident.',
#     'path_pattern': '[[cause]]/N\t+nsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:a81196f3-2cd0-4825-aa85-3d8336da74d1',
#     'clueweb12_page_reference': 'http://www.training-conditioning.com/2007/06/01/hokies_regroup_in_wake_of_shootings/index.php',
#     'clueweb12_page_timestamp': '2012-02-20T14:31:45Z',
#     'sentence': "Whether it's an athletics-related death, death of a staff member, or a death resulting from an environmental event or an accident, I was surprised to think just how prevalent these events are.",
#     'path_pattern': '[[cause]]/N\t-nmod:from\tresulting/VBG\t-acl\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:e5565b74-e383-40c0-9168-ba978d562443',
#     'clueweb12_page_reference': 'http://dls.state.va.us/pubs/summary/2004/04sum35.htm',
#     'clueweb12_page_timestamp': '2012-02-23T09:45:04Z',
#     'sentence': 'Directs licensed emergency medical services agencies to release to the Commissioner of the Department of Labor and Industry, or his designee, certain prehospital patient care reports when such records are requested for a patient who has suffered an injury, disability, or death resulting from an accident or illness while engaged in his employment.',
#     'path_pattern': '[[cause]]/N\t-nmod:from\tresulting/VBG\t-acl\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:0c115c66-5cca-440e-8ae2-d10c53608bfb',
#     'clueweb12_page_reference': 'http://www.progressivedairy.com/hg/features/2009/0409/0409_hallada.html',
#     'clueweb12_page_timestamp': '2012-02-20T14:58:15Z',
#     'sentence': 'Even for those farm entities that can financially survive, an accident that results in serious injury or death can call into question the desire of key owners or employees to continue the business.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:9678ff74-0f7f-44c7-a82f-92b9c97ddb7c',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving',
#     'clueweb12_page_timestamp': '2012-02-22T02:22:30Z',
#     'sentence': 'You could be ordered to attend traffic survival school if you have 8-12 Arizona driving points on your license in the last year, are convicted of aggressive driving, caused an accident resulting in serious injury or death, received multiple moving violations within a year under the age of 18, or are caught running a red light.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:9678ff74-0f7f-44c7-a82f-92b9c97ddb7c',
#     'clueweb12_page_reference': 'http://arizona.drivinguniversity.com/defensive-driving',
#     'clueweb12_page_timestamp': '2012-02-22T02:22:30Z',
#     'sentence': 'Your ticket cannot be associated with an accident that caused a death or serious injury.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:9cbf44bd-3014-4822-8906-3898ed96917b',
#     'clueweb12_page_reference': 'http://www.wake-up.org/Alpha/Chapter4.htm',
#     'clueweb12_page_timestamp': '2012-02-19T02:56:11Z',
#     'sentence': 'Death caused by disease, accident or �natural causes� is the consequence of sin, but the penalty for sin is death by execution.',
#     'path_pattern': '[[cause]]/N\t-nmod:by\tcaused/VBN\t-acl\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:beb8b9a7-61da-4ab5-9f6d-ef133288f93e',
#     'clueweb12_page_reference': 'http://evans-experientialism.freewebspace.com/gustave_le_bon2.htm',
#     'clueweb12_page_timestamp': '2012-02-23T15:14:38Z',
#     'sentence': 'An accident which should have caused the death of only five hundred instead of five thousand persons, but on the same day and in public, as the outcome of an accident appealing strongly to the eye, by the fall, for instance, of the Eiffel Tower, would have produced, on the contrary, an immense impression on the imagination of the crowd.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBN\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:5c4622e1-3611-47db-a3d2-e6410cff5bc7',
#     'clueweb12_page_reference': 'http://www.nesgs.org/~swngs/newspaper/1910_republican.htm',
#     'clueweb12_page_timestamp': '2012-02-20T12:43:35Z',
#     'sentence': 'About two years ago he sustained an accident, a fall, that was ultimately the cause of his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:d26fa3ec-986d-4436-b709-883eb9122d64',
#     'clueweb12_page_reference': 'http://www.southerncaliforniadefenseblog.com/hit_and_run/',
#     'clueweb12_page_timestamp': '2012-02-18T22:47:34Z',
#     'sentence': 'Under this law, if you are involved in an accident that results in death or injury to another person, you are obligated to stop your vehicle, provide your identifying information, provide reasonable assistance to the injured party, and notify police if none have arrived on the scene.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:944c4c7e-dcc6-4803-b411-e771d4d3c452',
#     'clueweb12_page_reference': 'http://www.njatty.com/blog/auto-accident/',
#     'clueweb12_page_timestamp': '2012-02-18T23:27:32Z',
#     'sentence': 'In this particular story, if the woman had caused an accident that resulted in injury or death, she could have faced serious criminal penalties and civil liability.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresulted/VBD\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:944c4c7e-dcc6-4803-b411-e771d4d3c452',
#     'clueweb12_page_reference': 'http://www.njatty.com/blog/auto-accident/',
#     'clueweb12_page_timestamp': '2012-02-18T23:27:32Z',
#     'sentence': 'New Jersey Statutes 39:4-129 (a) (Action in case of an accident) states: “The driver of any vehicle, knowingly involved in an accident resulting in injury or death to any person shall immediately stop the vehicle at the scene of the accident or as close thereto as possible but shall then forthwith return to and in every event shall remain at the scene.”',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:ff8e13b9-e59a-429a-be08-05d6a7ee9c4b',
#     'clueweb12_page_reference': 'http://www.travelinsuranz.com/travel_insurance_articles/flight-travel-insurance.htm',
#     'clueweb12_page_timestamp': '2012-02-19T01:52:41Z',
#     'sentence': 'Flight accident insurance is coverage in case of an accident that causes death or dismemberment while traveling with the airline.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcauses/VBZ\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
# ...
#    'payload': {'clueweb12_page_id': 'urn:uuid:3d409b81-000b-4251-9b44-b3c18e92a3ad',
#     'clueweb12_page_reference': 'http://www.prca.org/standard_bearer/volume77/2001mar15.html',
#     'clueweb12_page_timestamp': '2012-03-04T23:56:38Z',
#     'sentence': "Even Quincy's forensic science was all about trying to determine whether a death was due to an accident, natural causes, or the design of an intelligence.",
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:32f50391-c417-4716-bb44-543a54e7878a',
#     'clueweb12_page_reference': 'http://www.pagenweb.org/~luzerne/bios/sabios.htm',
#     'clueweb12_page_timestamp': '2012-03-05T12:55:56Z',
#     'sentence': 'His death was the result of an accident, the crushing of his arm in a cider mill.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:1def9879-d0f4-4e68-bc77-52d1d21b14b8',
#     'clueweb12_page_reference': 'http://www.lorrypatton.com/travel/gtips/2272.html',
#     'clueweb12_page_timestamp': '2012-03-03T17:59:09Z',
#     'sentence': "If you cause an accident that results in a death, you can be sentenced to three to six months' imprisonment.",
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:82d4cfa8-5cb4-4e8e-8ad4-4ab8a7826a15',
#     'clueweb12_page_reference': 'http://www.nutramed.com/brain/psychiatry.htm',
#     'clueweb12_page_timestamp': '2012-03-04T03:05:33Z',
#     'sentence': 'Several drugs at once confuse the mind, may be dangerous and may cause death by accident or suicide.',
#     'path_pattern': '[[cause]]/N\t-nmod:by\tcause/VB\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:f93d97b1-f290-46e1-85a4-9bd4ba51cd57',
#     'clueweb12_page_reference': 'http://kmblegal.com/legal_topics/whistleblower-law/railroad/',
#     'clueweb12_page_timestamp': '2012-03-04T23:43:02Z',
#     'sentence': 'This includes furnishing information to regarding an accident resulting in death or injury to a person in connection with railroad transportation.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:b771af8a-024b-437f-a5bc-d59e68139ea6',
#     'clueweb12_page_reference': 'http://www.texas-dwi-defense.com/DWI/Failure-To-Stop.aspx',
#     'clueweb12_page_timestamp': '2012-03-04T10:54:49Z',
#     'sentence': 'If the accident caused life-threatening injuries or a death, the charge becomes a felony.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:9b49d53a-912e-4408-a74d-6d11467b989d',
#     'clueweb12_page_reference': 'http://www.invent.org/hall_of_fame/1_3_0_induction_roebling.asp',
#     'clueweb12_page_timestamp': '2012-03-02T11:44:49Z',
#     'sentence': 'However, as work was about to begin, he suffered an accident that led to his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tled/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:5932fef9-66a8-4602-831c-c6c5ed038559',
#     'clueweb12_page_reference': 'http://www.laborcommission.utah.gov/newSite/divisions/Adjudication/AppealWorkersCompensationAppeal.html',
#     'clueweb12_page_timestamp': '2012-03-02T03:49:56Z',
#     'sentence': 'There are also separate forms for death claims, depending on whether the death was due to an accident or was the result of occupational disease.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:2f42d72f-b6e2-425d-80fc-ba92cefbeb9c',
#     'clueweb12_page_reference': 'http://www.njatty.com/blog/tag/serious-injury-accident/',
#     'clueweb12_page_timestamp': '2012-03-02T13:02:53Z',
#     'sentence': 'New Jersey Statutes 39:4-129 (a) (Action in case of an accident) states: “The driver of any vehicle, knowingly involved in an accident resulting in injury or death to any person shall immediately stop the vehicle at the scene of the accident or as close thereto as possible but shall then forthwith return to and in every event shall remain at the scene.”',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:7d6c60ae-6218-4631-a6e1-475de4bd8bce',
#     'clueweb12_page_reference': 'http://www.galliagenealogy.org/Civil%20War/CW_obits/cwobits_d-g.htm',
#     'clueweb12_page_timestamp': '2012-03-01T22:36:48Z',
#     'sentence': 'The accident which caused his death was as follows.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c79398d0-04d0-4d6b-aff5-b3b32e860c73',
#     'clueweb12_page_reference': 'http://www.injurytriallawyer.com/library/wrongful-death-expert-witnesses-l-seattle-attorney.cfm',
#     'clueweb12_page_timestamp': '2012-03-01T12:21:07Z',
#     'sentence': "Usually, the person's field of expertise will depend on the circumstances that lead to the accident that caused death.",
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:ae980a5b-47ff-4103-8df9-7363980cbb80',
#     'clueweb12_page_reference': 'https://www.ethiopianairlines.com/en/travel/policies/contract.aspx',
#     'clueweb12_page_timestamp': '2012-03-02T00:39:02Z',
#     'sentence': 'Pursuant to these Conventions, the Carrier would be liable for damage sustained in case of death or bodily injury of a passenger upon condition only that the accident which caused the death or injury took place on board the aircraft or in the course of any of the operations of embarking or disembarking.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:06130f9a-9464-42f6-8ad4-0ded66a1214c',
#     'clueweb12_page_reference': 'http://www.johntfloyd.com/comments/september10/No-Refusal-DWI-Attorney.htm',
#     'clueweb12_page_timestamp': '2012-03-02T10:49:49Z',
#     'sentence': 'The DWI law, as it existed at the time, allowed motorists to refuse blood or breath samples unless they were involved in an accident which caused death or serious injury.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcaused/VBD\t+dobj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:1c77b364-4ba1-4a82-a474-d88366a5d248',
#     'clueweb12_page_reference': 'http://www.microcapital.org/microcapital-brief-manulife-financial-introduces-life-microinsurance-product-for-philippines-plans-to-expand-sales-in-vietnam/',
#     'clueweb12_page_timestamp': '2012-03-02T14:45:56Z',
#     'sentence': 'However, if the death is the result of an accident, the policy pays 300 percent of the standard coverage amount.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:a41a79e6-ed4d-4c44-a3d4-5015e09b86c3',
#     'clueweb12_page_reference': 'http://www.djmcadam.com/book-auctions.html',
#     'clueweb12_page_timestamp': '2012-03-01T18:39:20Z',
#     'sentence': 'Sam�we employ the little familiarity by which he was universally known�was born in 1728 in the parish of St. Paul, Covent Garden, and lived on till 1802, his death being the result of an accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:0944dbf1-fa8e-4c27-a5d1-8c45117b97f3',
#     'clueweb12_page_reference': 'http://www.mcusa-archives.org/MennObits/27/jul1927.html',
#     'clueweb12_page_timestamp': '2012-03-02T23:42:56Z',
#     'sentence': 'Death was due to an accident during hay making when a harpoon which he was tending suddenly descended from the carrier and pierced his abdomen.',
#     'path_pattern': '[[cause]]/N\t-nmod:to\tdue/JJ\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:0944dbf1-fa8e-4c27-a5d1-8c45117b97f3',
#     'clueweb12_page_reference': 'http://www.mcusa-archives.org/MennObits/27/jul1927.html',
#     'clueweb12_page_timestamp': '2012-03-02T23:42:56Z',
#     'sentence': 'Her death was caused by accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:agent\tcaused/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:5f4ce999-abb1-4cf7-8d69-560956c55f5c',
#     'clueweb12_page_reference': 'http://www.daviddfriedman.com/Academic/Course_Pages/21st_century_issues/legal_issues_21_2000_pprs_web/21st_c_papers_2003/CedorInternalSurveillance.htm',
#     'clueweb12_page_timestamp': '2012-03-02T01:40:23Z',
#     'sentence': 'With current surveillance technology, a murderer might be able to escape liability for a videotaped murder by staging an accident where a jury would determine that the death was actually caused by accident.',
#     'path_pattern': '[[cause]]/N\t-nmod:agent\tcaused/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:391a7eba-60aa-4c86-9d15-7bdef9c4e392',
#     'clueweb12_page_reference': 'http://www.kyagr.com/pr/newscenter/kentuckykingdomreport.htm',
#     'clueweb12_page_timestamp': '2012-03-02T08:34:40Z',
#     'sentence': 'It requires ride owners to notify the Department within 12 hours of an accident that results in death, injury requiring medical treatment other than first aid, or damage to a ride that renders it unsafe.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:d55b386e-b9ae-48f8-aa49-b43adb1d0f3d',
#     'clueweb12_page_reference': 'http://www.kyagr.com/pr/newscenter/sb203passessenate.htm',
#     'clueweb12_page_timestamp': '2012-03-02T08:11:22Z',
#     'sentence': 'It requires ride owners to notify the Department within 12 hours of an accident that results in death, injury requiring medical treatment other than first aid, or damage to a ride that renders it unsafe.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:8655555f-db3d-441a-8d83-406f3f0d9f83',
#     'clueweb12_page_reference': 'http://www.lindapages.com/marshall/obitc.htm',
#     'clueweb12_page_timestamp': '2012-03-02T13:04:21Z',
#     'sentence': 'His death was caused by an accident while on his way to work for the B & O Railroad.',
#     'path_pattern': '[[cause]]/N\t-nmod:agent\tcaused/VBN\t+nsubjpass\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c06945de-b7e4-4e6a-830b-62f3d52b6a91',
#     'clueweb12_page_reference': 'http://www.cityofhawarden.com/?page_id=1520',
#     'clueweb12_page_timestamp': '2012-03-01T20:34:14Z',
#     'sentence': 'Whenever an ATV or snowmobile is involved in an accident resulting in injury or death to anyone or property damage amounting to one thousand dollars ($1000.00) or more, either the operator or someone acting for the operator shall immediately notify a law enforcement officer and shall file an accident report, in accordance with State law.',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:c98dbba6-9551-4207-8ac5-a16e008f9f79',
#     'clueweb12_page_reference': 'http://www.njatty.com/blog/tag/new-jersey-accident-lawyer/',
#     'clueweb12_page_timestamp': '2012-03-03T03:15:21Z',
#     'sentence': 'The law states: “The driver of any vehicle, knowingly involved in an accident resulting in injury or death to any person shall immediately stop the vehicle at the scene of the accident or as close thereto as possible, but shall then forthwith return to and in every event shall remain at the scene until he has fulfilled the requirements of subsection (c) of this section.”',
#     'path_pattern': '[[cause]]/N\t+acl\tresulting/VBG\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:b60a32fa-9ce0-4b80-aeb0-2e3e739a4a47',
#     'clueweb12_page_reference': 'http://www.jcs-group.com/fun/travels/inquisitive.html',
#     'clueweb12_page_timestamp': '2012-03-02T23:14:07Z',
#     'sentence': 'Proceedings in Case of Death - If a man of the party dies, write down a detailed account of the matter, and have it attested by the others; especially if accident be the cause of his death.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tcause/NN\t+nmod:of\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:58c625ae-a2ba-47fc-be87-15eaf5f29136',
#     'clueweb12_page_reference': 'http://www.iagenweb.org/sioux/books/british/british_2_18.htm',
#     'clueweb12_page_timestamp': '2012-03-02T15:29:51Z',
#     'sentence': 'The unfortunate man had but recently returned from England with a shoulder badly bruised in hunting - with upper arm strapped to his body and only the hand free to drive, he was unable to manage his mount well enough to avoid the accident which led to his death before the eyes of Mrs. Among the participants in this contest at Crescent Park, Sioux City, were Jack Watson, A. C. Colledge, G. C. Maclagan, and Count von Mueller for Le Mars and Henry Drake for Sioux City.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tled/VBD\t+nmod:to\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:3bdc818b-9c59-4675-a5c3-4edaab559340',
#     'clueweb12_page_reference': 'http://www.findarticlesworld.com/finance-investment/article2502.htm',
#     'clueweb12_page_timestamp': '2012-03-02T05:09:21Z',
#     'sentence': 'However, if death was a result of an accident, or if death due to natural causes occurs after the two years, your beneficiary will receive the full benefit amount.',
#     'path_pattern': '[[cause]]/N\t-nmod:of\tresult/NN\t+nsubj\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:6693d76e-6f12-4054-8d27-d67806fd3baf',
#     'clueweb12_page_reference': 'http://www.fin.ucar.edu/riskmgmt/auto_ins.html',
#     'clueweb12_page_timestamp': '2012-03-02T05:43:37Z',
#     'sentence': 'If the accident results in serious injury or death, the Insurance Manager and/or the Associate Vice-President for Business Services must be contacted immediately.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:f04e530a-952c-4b33-96a0-6c95041426b9',
#     'clueweb12_page_reference': 'http://www.fin.ucar.edu/polpro/section4/4-5.html',
#     'clueweb12_page_timestamp': '2012-03-02T05:40:10Z',
#     'sentence': 'If the accident results in serious injury or death, the Insurance Manager and/or the Associate Vice-President for Business Services must be contacted immediately.',
#     'path_pattern': '[[cause]]/N\t-nsubj\tresults/VBZ\t+nmod:in\t[[effect]]/N'}},
#   {'type': 'clueweb12_sentence',
#    'payload': {'clueweb12_page_id': 'urn:uuid:954498dd-7ef8-45cb-ba2c-eaeb23f25b53',
#     'clueweb12_page_reference': 'http://www.iowadot.gov/mvd/ods/accidents.htm',
#     'clueweb12_page_timestamp': '2012-03-02T23:09:00Z',
#     'sentence': 'An accident occurring anywhere within the State of Iowa causing death, personal injury, or total property damage of $1,500 or more must be reported on an Iowa Accident Report form.',
#     'path_pattern': '[[cause]]/N\t+acl\tcausing/VBG\t+dobj\t[[effect]]/N'}},
#   ...],
#  'support': 38}

# %%
from collections import defaultdict, deque

adj = defaultdict(set)
radj = defaultdict(set)

with path.open("r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        obj = json.loads(line)
        cr = obj["causal_relation"]
        cause = cr["cause"]["concept"]
        effect = cr["effect"]["concept"]
        adj[cause].add(effect)
        radj[effect].add(cause)

adj = {k: sorted(v) for k, v in adj.items()}
radj = {k: sorted(v) for k, v in radj.items()}

def reverse_bfs_distance(radj, target):
    dist = {target: 0}
    q = deque([target])
    while q:
        node = q.popleft()
        for prev in radj.get(node, []):
            if prev not in dist:
                dist[prev] = dist[node] + 1
                q.append(prev)
    return dist

dist_to_death = reverse_bfs_distance(radj, "death")
print("graph built:", "causes", len(adj), "effects", len(radj), "nodes_reaching_death", len(dist_to_death))
# Out:
# graph built: causes 51863 effects 38324 nodes_reaching_death 39370

# %%
TARGET = "death"
MIN_HOPS = 3
MAX_HOPS = 4

layer = {TARGET}
exact = {}

for d in range(1, MAX_HOPS + 1):
    prev = set()
    for node in layer:
        prev.update(radj.get(node, []))
    layer = prev
    exact[d] = layer
    print(f"exact_hops={d}: {len(layer)} heads")

heads_union = set()
for d in range(MIN_HOPS, MAX_HOPS + 1):
    heads_union.update(exact.get(d, set()))
heads_union.discard(TARGET)

heads_any = set(dist_to_death.keys())
heads_any.discard(TARGET)

print(f"unique (head -> {TARGET}) pairs with hops in [{MIN_HOPS}, {MAX_HOPS}]: {len(heads_union)}")
print(f"unique (head -> {TARGET}) pairs (any hops): {len(heads_any)}")
print("contains tobacco_smoking:", "tobacco_smoking" in heads_union)
# Out:
# exact_hops=1: 5168 heads
# exact_hops=2: 30791 heads
# exact_hops=3: 38558 heads
# exact_hops=4: 39291 heads
# unique (head -> death) pairs with hops in [3, 4]: 39290
# unique (head -> death) pairs (any hops): 39369
# contains tobacco_smoking: True

# %%
import json
import random
from pathlib import Path
import re
from collections import defaultdict, deque



MIN_HOPS = 4
MAX_HOPS = 4
SAMPLE_K = 120
SEED = 0

nodes = sorted(set(adj.keys()) | set(radj.keys()))
node2id = {n: i for i, n in enumerate(nodes)}
id2node = nodes

adj_i = [[] for _ in range(len(nodes))]
for cause, effects in adj.items():
    uid = node2id[cause]
    adj_i[uid] = [node2id[e] for e in effects]

radj_i = [[] for _ in range(len(nodes))]
for uid in range(len(nodes)):
    for vid in adj_i[uid]:
        radj_i[vid].append(uid)

stop = {
    'a','an','the','and','or','of','to','in','on','for','with','without','as','at','by','from','into','over','under',
    'is','are','was','were','be','been','being','due','after','before','during','between','within','among',
    'more','less','than'
}

def base_tokens(s: str):
    parts = re.split(r'[^A-Za-z0-9]+', s.lower())
    return [p for p in parts if p and p not in stop and len(p) >= 3]

def tokenize(s: str):
    toks = set()
    for t in base_tokens(s):
        toks.add(t)
        if len(t) >= 5:
            toks.add(t[:3])
            toks.add(t[-3:])
        if len(t) >= 8:
            toks.add(t[:4])
            toks.add(t[-4:])
    return toks

tokens_by_id = [tokenize(name) for name in id2node]
token_to_ids = defaultdict(list)
for i, toks in enumerate(tokens_by_id):
    for t in toks:
        token_to_ids[t].append(i)

seen_fwd = [0] * len(nodes)
seen_bwd = [0] * len(nodes)
mark = 0

def bfs(start: int, graph, seen, mark: int):
    q = deque([start])
    seen[start] = mark
    while q:
        u = q.popleft()
        for v in graph[u]:
            if seen[v] != mark:
                seen[v] = mark
                q.append(v)

rng = random.Random(SEED)
used_unrelated = set()

def pick_two_simple_paths_len4(uid):
    tails = {}
    for a in adj_i[uid]:
        if a == uid:
            continue
        for b in adj_i[a]:
            if b in (uid, a):
                continue
            for c in adj_i[b]:
                if c in (uid, a, b):
                    continue
                for tid in adj_i[c]:
                    if tid in (uid, a, b, c):
                        continue
                    p = [uid, a, b, c, tid]
                    lst = tails.setdefault(tid, [])
                    if len(lst) < 2:
                        lst.append(p)
                        if len(lst) == 2:
                            return tid, lst[0], lst[1]
    return None, None, None

head_ids = list(range(len(nodes)))
rng.shuffle(head_ids)

selected_pairs = []
for uid in head_ids:
    if len(selected_pairs) >= SAMPLE_K:
        break
    if not adj_i[uid]:
        continue

    tid, p1, p2 = pick_two_simple_paths_len4(uid)
    if tid is None:
        continue

    mark += 1
    bfs(uid, adj_i, seen_fwd, mark)
    bfs(uid, radj_i, seen_bwd, mark)

    head_tokens = tokens_by_id[uid]
    cand = set()
    for t in head_tokens:
        cand.update(token_to_ids.get(t, ()))
    cand.discard(uid)

    scored = []
    for cid in cand:
        if seen_fwd[cid] == mark or seen_bwd[cid] == mark:
            continue
        overlap = head_tokens & tokens_by_id[cid]
        if not overlap:
            continue
        scored.append(((sum(len(x) for x in overlap), len(overlap), rng.random()), cid))

    scored.sort(reverse=True)
    neg = None
    for _, cid in scored:
        if cid not in used_unrelated:
            neg = cid
            break
    if neg is None and scored:
        neg = scored[0][1]

    if neg is None:
        pool = [i for i in range(len(nodes)) if i != uid and seen_fwd[i] != mark and seen_bwd[i] != mark]
        rng.shuffle(pool)
        for cid in pool:
            if cid not in used_unrelated:
                neg = cid
                break
        if neg is None:
            neg = pool[0]

    used_unrelated.add(neg)
    selected_pairs.append(
        {
            'head': id2node[uid],
            'tail': id2node[tid],
            'min_hops': MIN_HOPS,
            'max_hops': MAX_HOPS,
            'chain_1': [id2node[x] for x in p1],
            'chain_2': [id2node[x] for x in p2],
            'unrelated_to_head': id2node[neg],
        }
    )

if len(selected_pairs) < SAMPLE_K:
    raise RuntimeError(f'Only found {len(selected_pairs)} pairs')

out_path = Path(f"results/causenet_head_tail_pairs_min{MIN_HOPS}_max{MAX_HOPS}_{SAMPLE_K}.jsonl")
out_path.parent.mkdir(parents=True, exist_ok=True)
with out_path.open("w", encoding="utf-8") as f:
    for rec in selected_pairs:
        f.write(json.dumps(rec, ensure_ascii=False) + "\n")

print("min_hops", MIN_HOPS, "max_hops", MAX_HOPS)
print("sample_pairs", len(selected_pairs))
print("saved", out_path)
selected_pairs[:2]
# Out:
# min_hops 4 max_hops 4
# sample_pairs 120
# saved results\causenet_head_tail_pairs_min4_max4_120.jsonl
# [{'head': 'butterfly',
#   'tail': 'anxiety',
#   'min_hops': 4,
#   'max_hops': 4,
#   'chain_1': ['butterfly', 'hurricane', 'changes', 'abuse', 'anxiety'],
#   'chain_2': ['butterfly', 'hurricane', 'changes', 'accidents', 'anxiety'],
#   'unrelated_to_head': "flap_of_a_butterfly_'s_wings_in_brazil"},
#  {'head': 'metabolic_rate',
#   'tail': 'complications',
#   'min_hops': 4,
#   'max_hops': 4,
#   'chain_1': ['metabolic_rate',
#    'fat_loss',
#    'weight_loss',
#    'anemia',
#    'complications'],
#   'chain_2': ['metabolic_rate',
#    'fat_loss',
#    'weight_loss',
#    'anorexia',
#    'complications'],
#   'unrelated_to_head': 'low_metabolic_rate'}]

# %%
START = "tobacco_smoking"
MID = "lung_cancer"
TARGET = "death"

MIN_HOPS = 4
MAX_HOPS = 6
MAX_SHOW_PER_HOPS = 20

prefix = [START, MID]
if MID not in adj.get(START, []):
    raise ValueError(f"Missing edge: {START} -> {MID}")

def iter_simple_paths_exact_hops(adj, dist_to_target, start_path, target, total_hops, limit=None):
    stack = [(start_path[-1], start_path, set(start_path))]
    found = 0
    while stack:
        node, path_nodes, seen = stack.pop()
        hops = len(path_nodes) - 1

        d = dist_to_target.get(node)
        if d is None or d > total_hops - hops:
            continue

        if hops == total_hops:
            if node == target:
                yield path_nodes
                found += 1
                if limit is not None and found >= limit:
                    return
            continue

        for nxt in reversed(adj.get(node, [])):
            if nxt in seen:
                continue
            stack.append((nxt, path_nodes + [nxt], seen | {nxt}))

paths_by_hops = {}
for hops in range(MIN_HOPS, MAX_HOPS + 1):
    paths = list(iter_simple_paths_exact_hops(adj, dist_to_death, prefix, TARGET, hops, limit=MAX_SHOW_PER_HOPS))
    paths_by_hops[hops] = paths
    print(f"hops={hops}: showing {len(paths)} paths")
    for p in paths:
        print("  " + " -> ".join(p))
# Out:
# hops=4: showing 20 paths
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> death
#   tobacco_smoking -> lung_cancer -> cancer -> abnormalities -> death
#   tobacco_smoking -> lung_cancer -> cancer -> aging -> death
#   tobacco_smoking -> lung_cancer -> cancer -> ailments -> death
#   tobacco_smoking -> lung_cancer -> cancer -> anaemia -> death
#   tobacco_smoking -> lung_cancer -> cancer -> anemia -> death
#   tobacco_smoking -> lung_cancer -> cancer -> anorexia -> death
#   tobacco_smoking -> lung_cancer -> cancer -> anxiety -> death
#   tobacco_smoking -> lung_cancer -> cancer -> arthritis -> death
#   tobacco_smoking -> lung_cancer -> cancer -> asbestos -> death
#   tobacco_smoking -> lung_cancer -> cancer -> asbestos_exposure -> death
#   tobacco_smoking -> lung_cancer -> cancer -> bacteria -> death
#   tobacco_smoking -> lung_cancer -> cancer -> birth_defects -> death
#   tobacco_smoking -> lung_cancer -> cancer -> bleeding -> death
#   tobacco_smoking -> lung_cancer -> cancer -> blindness -> death
#   tobacco_smoking -> lung_cancer -> cancer -> blockage -> death
#   tobacco_smoking -> lung_cancer -> cancer -> blockages -> death
#   tobacco_smoking -> lung_cancer -> cancer -> blood_clots -> death
#   tobacco_smoking -> lung_cancer -> cancer -> bone_fractures -> death
#   tobacco_smoking -> lung_cancer -> cancer -> brain_cancer -> death
# hops=5: showing 20 paths
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> aggressive_behavior -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> aging -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> alcohol_abuse -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> alcoholism -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> allergies -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> anemia -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> anger -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> anxiety -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> arthritis -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> asthma -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> asthma_attack -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> behavior -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> bleeding -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> bouts -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> breast_cancer -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> cancer -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> cardiac_arrhythmia -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> cardiomyopathy -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> changes -> death
# hops=6: showing 20 paths
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> abdominal_pain -> anorexia -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> abdominal_pain -> cholecystitis -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> abdominal_pain -> diarrhea -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> abdominal_pain -> fever -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> abdominal_pain -> pain -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> ailments -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> anger -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> anxiety -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> behavior -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> behaviors -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> behaviour -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> brain_damage -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> chaos -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> chemicals -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> condition -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> conditions -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> crime -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> crimes -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> criminal_activity -> death
#   tobacco_smoking -> lung_cancer -> brain_metastasis -> symptoms -> addiction -> criminal_behavior -> death
